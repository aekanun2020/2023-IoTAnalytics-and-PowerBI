# %%
# ปรับแต่งค่าการทำงานของ Spark
from pyspark.sql import SparkSession

spark = SparkSession.\
        builder.\
        appName("KafkaSubscribe").\
        master("spark://spark-master:7077").\
        config("spark.executor.memory", "1000m").\
        config("spark.executor.cores", "2").\
        config("spark.cores.max", "6").\
        config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.12:3.0.0").\
        getOrCreate()
# Out:
# Ivy Default Cache set to: /root/.ivy2/cache
# The jars for the packages stored in: /root/.ivy2/jars
# :: loading settings :: url = jar:file:/usr/local/lib/python3.9/dist-packages/pyspark/jars/ivy-2.4.0.jar!/org/apache/ivy/core/settings/ivysettings.xml
# org.apache.spark#spark-sql-kafka-0-10_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-57cfc41f-ca37-4c14-83a1-2eee6ae21903;1.0
# 	confs: [default]
# 	found org.apache.spark#spark-sql-kafka-0-10_2.12;3.0.0 in central
# 	found org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.0.0 in central
# 	found org.apache.kafka#kafka-clients;2.4.1 in central
# 	found com.github.luben#zstd-jni;1.4.4-3 in central
# 	found org.lz4#lz4-java;1.7.1 in central
# 	found org.xerial.snappy#snappy-java;1.1.7.5 in central
# 	found org.slf4j#slf4j-api;1.7.30 in central
# 	found org.spark-project.spark#unused;1.0.0 in central
# 	found org.apache.commons#commons-pool2;2.6.2 in central
# :: resolution report :: resolve 613ms :: artifacts dl 14ms
# 	:: modules in use:
# 	com.github.luben#zstd-jni;1.4.4-3 from central in [default]
# 	org.apache.commons#commons-pool2;2.6.2 from central in [default]
# 	org.apache.kafka#kafka-clients;2.4.1 from central in [default]
# 	org.apache.spark#spark-sql-kafka-0-10_2.12;3.0.0 from central in [default]
# 	org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.0.0 from central in [default]
# 	org.lz4#lz4-java;1.7.1 from central in [default]
# 	org.slf4j#slf4j-api;1.7.30 from central in [default]
# 	org.spark-project.spark#unused;1.0.0 from central in [default]
# 	org.xerial.snappy#snappy-java;1.1.7.5 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   9   |   0   |   0   |   0   ||   9   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-57cfc41f-ca37-4c14-83a1-2eee6ae21903
# 	confs: [default]
# 	0 artifacts copied, 9 already retrieved (0kB/12ms)
# 23/06/19 11:25:13 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
rawMetadata_df = spark \
  .readStream \
  .format("kafka") \
  .option("kafka.bootstrap.servers", "10.128.0.12:9092") \
  .option("subscribe", "quickstart-events") \
  .option("group.id", "Aekanun-Spark-App") \
  .load()

# %%
from pyspark.sql import functions as sparkf

# %%
rawMetadata_df.printSchema()
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)

# %%
# เลือกเฉพาะคอลัมน์ที่ต้องการ
onlyMetadata_df = rawMetadata_df.selectExpr("CAST(key AS STRING)", "CAST(value AS STRING)")

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import from_json, col

# Main schema
schema = StructType([
    StructField("locationId", StringType()),
    StructField("location", StringType()),
    StructField("parameter", StringType()),
    StructField("value", StringType()),
    StructField("date", StringType()),
    StructField("unit", StringType()),
    StructField("coordinates", StringType()),
    StructField("country", StringType()),
    StructField("city", StringType()),
    StructField("isMobile", StringType()),
    StructField("isAnalysis", StringType()),
    StructField("entity", StringType()),
    StructField("sensorType", StringType())
])

# Nested 'date' and 'coordinates' schema
date_schema = StructType([
    StructField("utc", StringType()),
    StructField("local", StringType())
])

coordinates_schema = StructType([
    StructField("latitude", DoubleType()),
    StructField("longitude", DoubleType())
])

# Parse the JSON string column and convert it to a struct.
parsedData_df = onlyMetadata_df.withColumn("data", from_json("value", schema))

# %%
parsedData_df.printSchema()
# Out:
# root
#  |-- key: string (nullable = true)
#  |-- value: string (nullable = true)
#  |-- data: struct (nullable = true)
#  |    |-- locationId: string (nullable = true)
#  |    |-- location: string (nullable = true)
#  |    |-- parameter: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |    |-- date: string (nullable = true)
#  |    |-- unit: string (nullable = true)
#  |    |-- coordinates: string (nullable = true)
#  |    |-- country: string (nullable = true)
#  |    |-- city: string (nullable = true)
#  |    |-- isMobile: string (nullable = true)
#  |    |-- isAnalysis: string (nullable = true)
#  |    |-- entity: string (nullable = true)
#  |    |-- sensorType: string (nullable = true)

# %%
# Select only the nested fields
unNested_df = parsedData_df.select("key", "data.*")

# %%
unNested_df.printSchema()
# Out:
# root
#  |-- key: string (nullable = true)
#  |-- locationId: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- parameter: string (nullable = true)
#  |-- value: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- unit: string (nullable = true)
#  |-- coordinates: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- isMobile: string (nullable = true)
#  |-- isAnalysis: string (nullable = true)
#  |-- entity: string (nullable = true)
#  |-- sensorType: string (nullable = true)

# %%
# Parse the JSON string column and convert it to a struct.
unNested_df.withColumn("data", from_json("value", schema))\
.withColumn("date", from_json("date", date_schema))\
.withColumn("coordinates", from_json("coordinates", coordinates_schema))\
.printSchema()
# Out:
# root
#  |-- key: string (nullable = true)
#  |-- locationId: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- parameter: string (nullable = true)
#  |-- value: string (nullable = true)
#  |-- date: struct (nullable = true)
#  |    |-- utc: string (nullable = true)
#  |    |-- local: string (nullable = true)
#  |-- unit: string (nullable = true)
#  |-- coordinates: struct (nullable = true)
#  |    |-- latitude: double (nullable = true)
#  |    |-- longitude: double (nullable = true)
#  |-- country: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- isMobile: string (nullable = true)
#  |-- isAnalysis: string (nullable = true)
#  |-- entity: string (nullable = true)
#  |-- sensorType: string (nullable = true)
#  |-- data: struct (nullable = true)
#  |    |-- locationId: string (nullable = true)
#  |    |-- location: string (nullable = true)
#  |    |-- parameter: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |    |-- date: string (nullable = true)
#  |    |-- unit: string (nullable = true)
#  |    |-- coordinates: string (nullable = true)
#  |    |-- country: string (nullable = true)
#  |    |-- city: string (nullable = true)
#  |    |-- isMobile: string (nullable = true)
#  |    |-- isAnalysis: string (nullable = true)
#  |    |-- entity: string (nullable = true)
#  |    |-- sensorType: string (nullable = true)

# %%
extractedDateLatLong_df = unNested_df.withColumn("data", from_json("value", schema))\
.withColumn("date", from_json("date", date_schema))\
.withColumn("coordinates", from_json("coordinates", coordinates_schema))\
.select('key',
 'locationId',
 'location',
 'parameter',
 'value',
 'date.*',
 'unit',
 'coordinates.*',
 'country',
 'city',
 'isMobile',
 'isAnalysis',
 'entity',
 'sensorType')

# %%
extractedDateLatLong_df.printSchema()
# Out:
# root
#  |-- key: string (nullable = true)
#  |-- locationId: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- parameter: string (nullable = true)
#  |-- value: string (nullable = true)
#  |-- utc: string (nullable = true)
#  |-- local: string (nullable = true)
#  |-- unit: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- country: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- isMobile: string (nullable = true)
#  |-- isAnalysis: string (nullable = true)
#  |-- entity: string (nullable = true)
#  |-- sensorType: string (nullable = true)

# %%
final_df = extractedDateLatLong_df\
.withColumn('sourceUnixSTP',sparkf.unix_timestamp(sparkf.col('utc'), "yyyy-MM-dd'T'HH:mm:ssXXX"))

# %%
final_df.columns
# Out:
# ['key',
#  'locationId',
#  'location',
#  'parameter',
#  'value',
#  'utc',
#  'local',
#  'unit',
#  'latitude',
#  'longitude',
#  'country',
#  'city',
#  'isMobile',
#  'isAnalysis',
#  'entity',
#  'sensorType',
#  'sourceUnixSTP']

# %%
final_df.printSchema()
# Out:
# root
#  |-- key: string (nullable = true)
#  |-- locationId: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- parameter: string (nullable = true)
#  |-- value: string (nullable = true)
#  |-- utc: string (nullable = true)
#  |-- local: string (nullable = true)
#  |-- unit: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- country: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- isMobile: string (nullable = true)
#  |-- isAnalysis: string (nullable = true)
#  |-- entity: string (nullable = true)
#  |-- sensorType: string (nullable = true)
#  |-- sourceUnixSTP: long (nullable = true)

# %%
#agg_df = final_df.groupBy('value').agg(sparkf.max(sparkf.col('value')))

# %%
from pyspark.sql import functions as F

def max_value(df, epoch_id):
    df = df.withColumn("value", df["value"].cast("float"))
    max_value_row = df.orderBy(df.value.desc()).first()
    if max_value_row is not None and max_value_row.value > 60:
        print(f"ALERT! Batch: {epoch_id}, Max value: {max_value_row.value} exceeded 60 at date: {max_value_row.local}!")
    elif max_value_row is not None:
        print(f"Batch: {epoch_id}, Max value: {max_value_row.value} at date: {max_value_row.local}")
    else:
        print(f"Batch: {epoch_id}, No data")

query = final_df.writeStream \
    .foreachBatch(max_value) \
    .outputMode("update") \
    .start()

query.awaitTermination()
# Out:
# 23/06/19 11:25:23 WARN StreamingQueryManager: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-5a85b451-f214-40f5-94f1-449b20346d42. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# Batch: 0, No data
# Batch: 1, Max value: 36.0 at date: 2023-01-01T01:00:00+07:00
# Batch: 2, Max value: 38.0 at date: 2023-01-02T22:00:00+07:00
# Batch: 3, Max value: 38.0 at date: 2023-01-03T00:00:00+07:00
# Batch: 4, Max value: 29.0 at date: 2023-01-05T03:00:00+07:00
# Batch: 5, Max value: 29.0 at date: 2023-01-05T07:00:00+07:00
# Batch: 6, Max value: 30.0 at date: 2023-01-05T11:00:00+07:00
# Batch: 7, Max value: 30.0 at date: 2023-01-05T12:00:00+07:00
# Batch: 8, Max value: 30.0 at date: 2023-01-05T18:00:00+07:00
# Batch: 9, Max value: 30.0 at date: 2023-01-05T20:00:00+07:00
# Batch: 10, Max value: 32.0 at date: 2023-01-06T00:00:00+07:00
# Batch: 11, Max value: 34.0 at date: 2023-01-06T04:00:00+07:00
# Batch: 12, Max value: 35.0 at date: 2023-01-06T05:00:00+07:00
# Batch: 13, Max value: 34.0 at date: 2023-01-06T08:00:00+07:00
# Batch: 14, Max value: 33.0 at date: 2023-01-06T10:00:00+07:00
# Batch: 15, Max value: 32.0 at date: 2023-01-06T12:00:00+07:00
# Batch: 16, Max value: 32.0 at date: 2023-01-06T15:00:00+07:00
# Batch: 17, Max value: 32.0 at date: 2023-01-06T17:00:00+07:00
# Batch: 18, Max value: 32.0 at date: 2023-01-06T19:00:00+07:00
# Batch: 19, Max value: 32.0 at date: 2023-01-06T21:00:00+07:00
# Batch: 20, Max value: 32.0 at date: 2023-01-06T23:00:00+07:00
# Batch: 21, Max value: 32.0 at date: 2023-01-07T01:00:00+07:00
# Batch: 22, Max value: 31.0 at date: 2023-01-07T03:00:00+07:00
# Batch: 23, Max value: 30.0 at date: 2023-01-07T05:00:00+07:00
# Batch: 24, Max value: 29.0 at date: 2023-01-07T07:00:00+07:00
# Batch: 25, Max value: 29.0 at date: 2023-01-07T09:00:00+07:00
# Batch: 26, Max value: 29.0 at date: 2023-01-07T11:00:00+07:00
# Batch: 27, Max value: 30.0 at date: 2023-01-07T13:00:00+07:00
# Batch: 28, Max value: 30.0 at date: 2023-01-07T15:00:00+07:00
# Batch: 29, Max value: 31.0 at date: 2023-01-07T16:00:00+07:00
# Batch: 30, Max value: 32.0 at date: 2023-01-07T19:00:00+07:00
# Batch: 31, Max value: 33.0 at date: 2023-01-07T21:00:00+07:00
# Batch: 32, Max value: 34.0 at date: 2023-01-07T22:00:00+07:00
# Batch: 33, Max value: 34.0 at date: 2023-01-08T00:00:00+07:00
# Batch: 34, Max value: 36.0 at date: 2023-01-08T02:00:00+07:00
# Batch: 35, Max value: 37.0 at date: 2023-01-08T04:00:00+07:00
# Batch: 36, Max value: 39.0 at date: 2023-01-08T05:00:00+07:00
# Batch: 37, Max value: 41.0 at date: 2023-01-08T06:00:00+07:00
# Batch: 38, Max value: 41.0 at date: 2023-01-08T09:00:00+07:00
# Batch: 39, Max value: 42.0 at date: 2023-01-08T10:00:00+07:00
# Batch: 40, Max value: 44.0 at date: 2023-01-08T12:00:00+07:00
# Batch: 41, Max value: 46.0 at date: 2023-01-08T14:00:00+07:00
# Batch: 42, Max value: 47.0 at date: 2023-01-08T16:00:00+07:00
# Batch: 43, Max value: 47.0 at date: 2023-01-08T17:00:00+07:00
# Batch: 44, Max value: 47.0 at date: 2023-01-08T18:00:00+07:00
# Batch: 45, Max value: 48.0 at date: 2023-01-08T20:00:00+07:00
# Batch: 46, Max value: 48.0 at date: 2023-01-08T22:00:00+07:00
# Batch: 47, Max value: 48.0 at date: 2023-01-08T23:00:00+07:00
# Batch: 48, Max value: 48.0 at date: 2023-01-09T01:00:00+07:00
# Batch: 49, Max value: 49.0 at date: 2023-01-09T03:00:00+07:00
# Batch: 50, Max value: 49.0 at date: 2023-01-09T04:00:00+07:00
# Batch: 51, Max value: 50.0 at date: 2023-01-09T07:00:00+07:00
# Batch: 52, Max value: 50.0 at date: 2023-01-09T08:00:00+07:00
# Batch: 53, Max value: 50.0 at date: 2023-01-09T09:00:00+07:00
# Batch: 54, Max value: 51.0 at date: 2023-01-09T11:00:00+07:00
# Batch: 55, Max value: 51.0 at date: 2023-01-09T12:00:00+07:00
# Batch: 56, Max value: 51.0 at date: 2023-01-09T14:00:00+07:00
# Batch: 57, Max value: 51.0 at date: 2023-01-09T15:00:00+07:00
# Batch: 58, Max value: 51.0 at date: 2023-01-09T17:00:00+07:00
# Batch: 59, Max value: 51.0 at date: 2023-01-09T18:00:00+07:00
# Batch: 60, Max value: 52.0 at date: 2023-01-09T19:00:00+07:00
# Batch: 61, Max value: 53.0 at date: 2023-01-09T22:00:00+07:00
# Batch: 62, Max value: 53.0 at date: 2023-01-09T23:00:00+07:00
# Batch: 63, Max value: 53.0 at date: 2023-01-10T00:00:00+07:00
# Batch: 64, Max value: 53.0 at date: 2023-01-10T01:00:00+07:00
# Batch: 65, Max value: 53.0 at date: 2023-01-10T03:00:00+07:00
# Batch: 66, Max value: 52.0 at date: 2023-01-10T05:00:00+07:00
# Batch: 67, Max value: 53.0 at date: 2023-01-10T06:00:00+07:00
# Batch: 68, Max value: 53.0 at date: 2023-01-10T08:00:00+07:00
# Batch: 69, Max value: 53.0 at date: 2023-01-10T09:00:00+07:00
# Batch: 70, Max value: 54.0 at date: 2023-01-10T11:00:00+07:00
# Batch: 71, Max value: 54.0 at date: 2023-01-10T12:00:00+07:00
# Batch: 72, Max value: 53.0 at date: 2023-01-10T13:00:00+07:00
# Batch: 73, Max value: 52.0 at date: 2023-01-10T14:00:00+07:00
# Batch: 74, Max value: 51.0 at date: 2023-01-10T16:00:00+07:00
# Batch: 75, Max value: 51.0 at date: 2023-01-10T17:00:00+07:00
# Batch: 76, Max value: 49.0 at date: 2023-01-10T19:00:00+07:00
# Batch: 77, Max value: 48.0 at date: 2023-01-10T21:00:00+07:00
# Batch: 78, Max value: 46.0 at date: 2023-01-10T22:00:00+07:00
# Batch: 79, Max value: 46.0 at date: 2023-01-10T23:00:00+07:00
# Batch: 80, Max value: 44.0 at date: 2023-01-11T01:00:00+07:00
# Batch: 81, Max value: 44.0 at date: 2023-01-11T03:00:00+07:00
# Batch: 82, Max value: 44.0 at date: 2023-01-11T04:00:00+07:00
# Batch: 83, Max value: 43.0 at date: 2023-01-11T06:00:00+07:00
# Batch: 84, Max value: 42.0 at date: 2023-01-11T07:00:00+07:00
# Batch: 85, Max value: 39.0 at date: 2023-01-11T09:00:00+07:00
# Batch: 86, Max value: 35.0 at date: 2023-01-11T11:00:00+07:00
# Batch: 87, Max value: 34.0 at date: 2023-01-11T12:00:00+07:00
# Batch: 88, Max value: 34.0 at date: 2023-01-11T13:00:00+07:00
# Batch: 89, Max value: 33.0 at date: 2023-01-11T15:00:00+07:00
# Batch: 90, Max value: 33.0 at date: 2023-01-11T17:00:00+07:00
# Batch: 91, Max value: 33.0 at date: 2023-01-11T18:00:00+07:00
# Batch: 92, Max value: 33.0 at date: 2023-01-11T19:00:00+07:00
# Batch: 93, Max value: 33.0 at date: 2023-01-11T21:00:00+07:00
# Batch: 94, Max value: 33.0 at date: 2023-01-11T22:00:00+07:00
# Batch: 95, Max value: 33.0 at date: 2023-01-11T23:00:00+07:00
# Batch: 96, Max value: 34.0 at date: 2023-01-12T01:00:00+07:00
# Batch: 97, Max value: 33.0 at date: 2023-01-17T06:00:00+07:00
# Batch: 98, Max value: 33.0 at date: 2023-01-17T08:00:00+07:00
# Batch: 99, Max value: 34.0 at date: 2023-01-17T10:00:00+07:00
# Batch: 100, Max value: 35.0 at date: 2023-01-17T11:00:00+07:00
# Batch: 101, Max value: 36.0 at date: 2023-01-17T13:00:00+07:00
# Batch: 102, Max value: 37.0 at date: 2023-01-17T14:00:00+07:00
# Batch: 103, Max value: 38.0 at date: 2023-01-17T15:00:00+07:00
# Batch: 104, Max value: 39.0 at date: 2023-01-17T17:00:00+07:00
# Batch: 105, Max value: 39.0 at date: 2023-01-17T18:00:00+07:00
# Batch: 106, Max value: 40.0 at date: 2023-01-17T19:00:00+07:00
# Batch: 107, Max value: 40.0 at date: 2023-01-17T20:00:00+07:00
# Batch: 108, Max value: 41.0 at date: 2023-01-17T21:00:00+07:00
# Batch: 109, Max value: 43.0 at date: 2023-01-18T00:00:00+07:00
# Batch: 110, Max value: 44.0 at date: 2023-01-18T01:00:00+07:00
# Batch: 111, Max value: 47.0 at date: 2023-01-18T03:00:00+07:00
# Batch: 112, Max value: 48.0 at date: 2023-01-18T04:00:00+07:00
# Batch: 113, Max value: 48.0 at date: 2023-01-18T05:00:00+07:00
# Batch: 114, Max value: 49.0 at date: 2023-01-18T06:00:00+07:00
# Batch: 115, Max value: 49.0 at date: 2023-01-18T07:00:00+07:00
# Batch: 116, Max value: 49.0 at date: 2023-01-18T09:00:00+07:00
# Batch: 117, Max value: 48.0 at date: 2023-01-18T10:00:00+07:00
# Batch: 118, Max value: 47.0 at date: 2023-01-18T11:00:00+07:00
# Batch: 119, Max value: 46.0 at date: 2023-01-18T12:00:00+07:00
# Batch: 120, Max value: 45.0 at date: 2023-01-18T14:00:00+07:00
# Batch: 121, Max value: 44.0 at date: 2023-01-18T15:00:00+07:00
# Batch: 122, Max value: 44.0 at date: 2023-01-18T16:00:00+07:00
# Batch: 123, Max value: 43.0 at date: 2023-01-18T17:00:00+07:00
# Batch: 124, Max value: 43.0 at date: 2023-01-18T19:00:00+07:00
# Batch: 125, Max value: 42.0 at date: 2023-01-18T20:00:00+07:00
# Batch: 126, Max value: 42.0 at date: 2023-01-18T21:00:00+07:00
# Batch: 127, Max value: 41.0 at date: 2023-01-18T23:00:00+07:00
# Batch: 128, Max value: 40.0 at date: 2023-01-19T00:00:00+07:00
# Batch: 129, Max value: 39.0 at date: 2023-01-19T01:00:00+07:00
# Batch: 130, Max value: 37.0 at date: 2023-01-19T03:00:00+07:00
# Batch: 131, Max value: 36.0 at date: 2023-01-19T04:00:00+07:00
# Batch: 132, Max value: 35.0 at date: 2023-01-19T05:00:00+07:00
# Batch: 133, Max value: 34.0 at date: 2023-01-19T07:00:00+07:00
# Batch: 134, Max value: 34.0 at date: 2023-01-19T08:00:00+07:00
# Batch: 135, Max value: 34.0 at date: 2023-01-19T10:00:00+07:00
# Batch: 136, Max value: 34.0 at date: 2023-01-19T11:00:00+07:00
# Batch: 137, Max value: 35.0 at date: 2023-01-19T13:00:00+07:00
# Batch: 138, Max value: 35.0 at date: 2023-01-19T14:00:00+07:00
# Batch: 139, Max value: 35.0 at date: 2023-01-19T15:00:00+07:00
# Batch: 140, Max value: 35.0 at date: 2023-01-19T16:00:00+07:00
# Batch: 141, Max value: 35.0 at date: 2023-01-19T18:00:00+07:00
# Batch: 142, Max value: 36.0 at date: 2023-01-19T19:00:00+07:00
# Batch: 143, Max value: 36.0 at date: 2023-01-19T21:00:00+07:00
# Batch: 144, Max value: 35.0 at date: 2023-01-19T22:00:00+07:00
# Batch: 145, Max value: 35.0 at date: 2023-01-19T23:00:00+07:00
# Batch: 146, Max value: 35.0 at date: 2023-01-20T01:00:00+07:00
# Batch: 147, Max value: 35.0 at date: 2023-01-20T02:00:00+07:00
# Batch: 148, Max value: 35.0 at date: 2023-01-20T03:00:00+07:00
# Batch: 149, Max value: 36.0 at date: 2023-01-20T06:00:00+07:00
# Batch: 150, Max value: 37.0 at date: 2023-01-20T07:00:00+07:00
# Batch: 151, Max value: 38.0 at date: 2023-01-20T09:00:00+07:00
# Batch: 152, Max value: 38.0 at date: 2023-01-20T10:00:00+07:00
# Batch: 153, Max value: 39.0 at date: 2023-01-20T11:00:00+07:00
# Batch: 154, Max value: 39.0 at date: 2023-01-20T12:00:00+07:00
# Batch: 155, Max value: 39.0 at date: 2023-01-20T14:00:00+07:00
# Batch: 156, Max value: 39.0 at date: 2023-01-20T15:00:00+07:00
# Batch: 157, Max value: 39.0 at date: 2023-01-20T16:00:00+07:00
# Batch: 158, Max value: 39.0 at date: 2023-01-20T18:00:00+07:00
# Batch: 159, Max value: 39.0 at date: 2023-01-20T19:00:00+07:00
# Batch: 160, Max value: 39.0 at date: 2023-01-20T20:00:00+07:00
# Batch: 161, Max value: 40.0 at date: 2023-01-20T22:00:00+07:00
# Batch: 162, Max value: 40.0 at date: 2023-01-20T23:00:00+07:00
# Batch: 163, Max value: 39.0 at date: 2023-01-21T01:00:00+07:00
# Batch: 164, Max value: 40.0 at date: 2023-01-21T02:00:00+07:00
# Batch: 165, Max value: 40.0 at date: 2023-01-21T03:00:00+07:00
# Batch: 166, Max value: 41.0 at date: 2023-01-21T04:00:00+07:00
# Batch: 167, Max value: 41.0 at date: 2023-01-21T06:00:00+07:00
# Batch: 168, Max value: 41.0 at date: 2023-01-21T07:00:00+07:00
# Batch: 169, Max value: 40.0 at date: 2023-01-21T08:00:00+07:00
# Batch: 170, Max value: 40.0 at date: 2023-01-21T09:00:00+07:00
# Batch: 171, Max value: 39.0 at date: 2023-01-21T11:00:00+07:00
# Batch: 172, Max value: 39.0 at date: 2023-01-21T12:00:00+07:00
# Batch: 173, Max value: 39.0 at date: 2023-01-21T13:00:00+07:00
# Batch: 174, Max value: 39.0 at date: 2023-01-21T15:00:00+07:00
# Batch: 175, Max value: 39.0 at date: 2023-01-21T16:00:00+07:00
# Batch: 176, Max value: 39.0 at date: 2023-01-21T17:00:00+07:00
# Batch: 177, Max value: 39.0 at date: 2023-01-21T18:00:00+07:00
# Batch: 178, Max value: 39.0 at date: 2023-01-21T20:00:00+07:00
# Batch: 179, Max value: 40.0 at date: 2023-01-21T21:00:00+07:00
# Batch: 180, Max value: 40.0 at date: 2023-01-21T22:00:00+07:00
# Batch: 181, Max value: 42.0 at date: 2023-01-22T00:00:00+07:00
# Batch: 182, Max value: 43.0 at date: 2023-01-22T01:00:00+07:00
# Batch: 183, Max value: 44.0 at date: 2023-01-22T02:00:00+07:00
# Batch: 184, Max value: 43.0 at date: 2023-01-22T03:00:00+07:00
# Batch: 185, Max value: 44.0 at date: 2023-01-22T05:00:00+07:00
# Batch: 186, Max value: 43.0 at date: 2023-01-22T06:00:00+07:00
# Batch: 187, Max value: 44.0 at date: 2023-01-22T07:00:00+07:00
# Batch: 188, Max value: 53.0 at date: 2023-01-23T08:00:00+07:00
# Batch: 189, Max value: 55.0 at date: 2023-01-23T09:00:00+07:00
# Batch: 190, Max value: 58.0 at date: 2023-01-23T11:00:00+07:00
# Batch: 191, Max value: 59.0 at date: 2023-01-23T12:00:00+07:00
# Batch: 192, Max value: 60.0 at date: 2023-01-23T13:00:00+07:00
# Batch: 193, Max value: 60.0 at date: 2023-01-23T14:00:00+07:00
# Batch: 194, Max value: 60.0 at date: 2023-01-23T15:00:00+07:00
# Batch: 195, Max value: 60.0 at date: 2023-01-23T16:00:00+07:00
# ALERT! Batch: 196, Max value: 61.0 exceeded 60 at date: 2023-01-23T19:00:00+07:00!
# ALERT! Batch: 197, Max value: 62.0 exceeded 60 at date: 2023-01-23T21:00:00+07:00!
# ALERT! Batch: 198, Max value: 61.0 exceeded 60 at date: 2023-01-23T23:00:00+07:00!
# ALERT! Batch: 199, Max value: 61.0 exceeded 60 at date: 2023-01-24T00:00:00+07:00!
# ALERT! Batch: 200, Max value: 61.0 exceeded 60 at date: 2023-01-24T01:00:00+07:00!
# ALERT! Batch: 201, Max value: 62.0 exceeded 60 at date: 2023-01-24T02:00:00+07:00!
# ALERT! Batch: 202, Max value: 63.0 exceeded 60 at date: 2023-01-24T04:00:00+07:00!
# ALERT! Batch: 203, Max value: 63.0 exceeded 60 at date: 2023-01-24T05:00:00+07:00!
# ALERT! Batch: 204, Max value: 63.0 exceeded 60 at date: 2023-01-24T06:00:00+07:00!
# ALERT! Batch: 205, Max value: 63.0 exceeded 60 at date: 2023-01-24T07:00:00+07:00!
# ALERT! Batch: 206, Max value: 63.0 exceeded 60 at date: 2023-01-24T08:00:00+07:00!
# ALERT! Batch: 207, Max value: 62.0 exceeded 60 at date: 2023-01-24T10:00:00+07:00!
# ALERT! Batch: 208, Max value: 62.0 exceeded 60 at date: 2023-01-24T11:00:00+07:00!
# ALERT! Batch: 209, Max value: 62.0 exceeded 60 at date: 2023-01-24T12:00:00+07:00!
# ALERT! Batch: 210, Max value: 62.0 exceeded 60 at date: 2023-01-24T13:00:00+07:00!
# ALERT! Batch: 211, Max value: 62.0 exceeded 60 at date: 2023-01-24T14:00:00+07:00!
# ALERT! Batch: 212, Max value: 62.0 exceeded 60 at date: 2023-01-24T16:00:00+07:00!
# ALERT! Batch: 213, Max value: 61.0 exceeded 60 at date: 2023-01-24T18:00:00+07:00!
# Batch: 214, Max value: 60.0 at date: 2023-01-24T19:00:00+07:00
# Batch: 215, Max value: 59.0 at date: 2023-01-24T20:00:00+07:00
# Batch: 216, Max value: 58.0 at date: 2023-01-24T21:00:00+07:00
# Batch: 217, Max value: 57.0 at date: 2023-01-24T22:00:00+07:00
# Batch: 218, Max value: 48.0 at date: 2023-01-25T05:00:00+07:00
# Batch: 219, Max value: 46.0 at date: 2023-01-25T06:00:00+07:00
# Batch: 220, Max value: 43.0 at date: 2023-01-25T07:00:00+07:00
# Batch: 221, Max value: 41.0 at date: 2023-01-25T08:00:00+07:00
# Batch: 222, Max value: 38.0 at date: 2023-01-25T09:00:00+07:00
# Batch: 223, Max value: 33.0 at date: 2023-01-25T11:00:00+07:00
# Batch: 224, Max value: 32.0 at date: 2023-01-25T12:00:00+07:00
# Batch: 225, Max value: 31.0 at date: 2023-01-25T13:00:00+07:00
# Batch: 226, Max value: 30.0 at date: 2023-01-25T14:00:00+07:00
# Batch: 227, Max value: 30.0 at date: 2023-01-25T15:00:00+07:00
# Batch: 228, Max value: 30.0 at date: 2023-01-25T16:00:00+07:00
# Batch: 229, Max value: 30.0 at date: 2023-01-25T18:00:00+07:00
# Batch: 230, Max value: 31.0 at date: 2023-01-25T19:00:00+07:00
# Batch: 231, Max value: 32.0 at date: 2023-01-25T20:00:00+07:00
# Batch: 232, Max value: 33.0 at date: 2023-01-25T22:00:00+07:00
# Batch: 233, Max value: 34.0 at date: 2023-01-25T23:00:00+07:00
# Batch: 234, Max value: 35.0 at date: 2023-01-26T00:00:00+07:00
# Batch: 235, Max value: 36.0 at date: 2023-01-26T01:00:00+07:00
# Batch: 236, Max value: 37.0 at date: 2023-01-26T02:00:00+07:00
# Batch: 237, Max value: 37.0 at date: 2023-01-26T03:00:00+07:00
# Batch: 238, Max value: 37.0 at date: 2023-01-26T04:00:00+07:00
# Batch: 239, Max value: 38.0 at date: 2023-01-26T05:00:00+07:00
# Batch: 240, Max value: 41.0 at date: 2023-01-26T07:00:00+07:00
# Batch: 241, Max value: 44.0 at date: 2023-01-26T08:00:00+07:00
# Batch: 242, Max value: 48.0 at date: 2023-01-26T09:00:00+07:00
# Batch: 243, Max value: 51.0 at date: 2023-01-26T10:00:00+07:00
# Batch: 244, Max value: 53.0 at date: 2023-01-26T11:00:00+07:00
# Batch: 245, Max value: 54.0 at date: 2023-01-26T12:00:00+07:00
# Batch: 246, Max value: 54.0 at date: 2023-01-26T13:00:00+07:00
# Batch: 247, Max value: 56.0 at date: 2023-01-26T15:00:00+07:00
# Batch: 248, Max value: 56.0 at date: 2023-01-26T17:00:00+07:00
# Batch: 249, Max value: 56.0 at date: 2023-01-26T18:00:00+07:00
# Batch: 250, Max value: 56.0 at date: 2023-01-26T19:00:00+07:00
# Batch: 251, Max value: 57.0 at date: 2023-01-26T20:00:00+07:00
# Batch: 252, Max value: 58.0 at date: 2023-01-26T21:00:00+07:00
# Batch: 253, Max value: 58.0 at date: 2023-01-26T23:00:00+07:00
# Batch: 254, Max value: 58.0 at date: 2023-01-27T00:00:00+07:00
# Batch: 255, Max value: 58.0 at date: 2023-01-27T01:00:00+07:00
# Batch: 256, Max value: 58.0 at date: 2023-01-27T02:00:00+07:00
# Batch: 257, Max value: 60.0 at date: 2023-01-27T03:00:00+07:00
# ALERT! Batch: 258, Max value: 62.0 exceeded 60 at date: 2023-01-27T04:00:00+07:00!
# ALERT! Batch: 259, Max value: 66.0 exceeded 60 at date: 2023-01-27T06:00:00+07:00!
# ALERT! Batch: 260, Max value: 66.0 exceeded 60 at date: 2023-01-27T07:00:00+07:00!
# ALERT! Batch: 261, Max value: 66.0 exceeded 60 at date: 2023-01-27T08:00:00+07:00!
# ALERT! Batch: 262, Max value: 65.0 exceeded 60 at date: 2023-01-27T09:00:00+07:00!
# ALERT! Batch: 263, Max value: 66.0 exceeded 60 at date: 2023-01-27T10:00:00+07:00!
# ALERT! Batch: 264, Max value: 67.0 exceeded 60 at date: 2023-01-27T12:00:00+07:00!
# ALERT! Batch: 265, Max value: 67.0 exceeded 60 at date: 2023-01-27T13:00:00+07:00!
# ALERT! Batch: 266, Max value: 68.0 exceeded 60 at date: 2023-01-27T14:00:00+07:00!
# ALERT! Batch: 267, Max value: 69.0 exceeded 60 at date: 2023-01-27T16:00:00+07:00!
# ALERT! Batch: 268, Max value: 69.0 exceeded 60 at date: 2023-01-27T18:00:00+07:00!
# ALERT! Batch: 269, Max value: 69.0 exceeded 60 at date: 2023-01-27T19:00:00+07:00!
# ALERT! Batch: 270, Max value: 69.0 exceeded 60 at date: 2023-01-27T20:00:00+07:00!
# ALERT! Batch: 271, Max value: 68.0 exceeded 60 at date: 2023-01-27T21:00:00+07:00!
# ALERT! Batch: 272, Max value: 68.0 exceeded 60 at date: 2023-01-27T22:00:00+07:00!
# ALERT! Batch: 273, Max value: 68.0 exceeded 60 at date: 2023-01-28T00:00:00+07:00!
# ALERT! Batch: 274, Max value: 68.0 exceeded 60 at date: 2023-01-28T01:00:00+07:00!
# ALERT! Batch: 275, Max value: 68.0 exceeded 60 at date: 2023-01-28T02:00:00+07:00!
# ALERT! Batch: 276, Max value: 68.0 exceeded 60 at date: 2023-01-28T03:00:00+07:00!
# ALERT! Batch: 277, Max value: 65.0 exceeded 60 at date: 2023-01-28T05:00:00+07:00!
# ALERT! Batch: 278, Max value: 62.0 exceeded 60 at date: 2023-01-28T07:00:00+07:00!
# Batch: 279, Max value: 58.0 at date: 2023-01-28T08:00:00+07:00
# Batch: 280, Max value: 54.0 at date: 2023-01-28T09:00:00+07:00
# Batch: 281, Max value: 48.0 at date: 2023-01-28T11:00:00+07:00
# Batch: 282, Max value: 47.0 at date: 2023-01-28T12:00:00+07:00
# Batch: 283, Max value: 46.0 at date: 2023-01-28T13:00:00+07:00
# Batch: 284, Max value: 45.0 at date: 2023-01-28T14:00:00+07:00
# Batch: 285, Max value: 44.0 at date: 2023-01-28T15:00:00+07:00
# Batch: 286, Max value: 43.0 at date: 2023-01-28T16:00:00+07:00
# Batch: 287, Max value: 43.0 at date: 2023-01-28T17:00:00+07:00
# Batch: 288, Max value: 42.0 at date: 2023-01-28T18:00:00+07:00
# Batch: 289, Max value: 41.0 at date: 2023-01-28T19:00:00+07:00
# Batch: 290, Max value: 40.0 at date: 2023-01-28T21:00:00+07:00
# Batch: 291, Max value: 39.0 at date: 2023-01-28T22:00:00+07:00
# Batch: 292, Max value: 39.0 at date: 2023-01-28T23:00:00+07:00
# Batch: 293, Max value: 38.0 at date: 2023-01-29T00:00:00+07:00
# Batch: 294, Max value: 37.0 at date: 2023-01-29T01:00:00+07:00
# Batch: 295, Max value: 36.0 at date: 2023-01-29T02:00:00+07:00
# Batch: 296, Max value: 35.0 at date: 2023-01-29T03:00:00+07:00
# Batch: 297, Max value: 34.0 at date: 2023-01-29T04:00:00+07:00
# Batch: 298, Max value: 34.0 at date: 2023-01-29T05:00:00+07:00
# Batch: 299, Max value: 34.0 at date: 2023-01-29T07:00:00+07:00
# Batch: 300, Max value: 35.0 at date: 2023-01-29T08:00:00+07:00
# Batch: 301, Max value: 36.0 at date: 2023-01-29T09:00:00+07:00
# Batch: 302, Max value: 36.0 at date: 2023-01-29T10:00:00+07:00
# Batch: 303, Max value: 36.0 at date: 2023-01-29T11:00:00+07:00
# Batch: 304, Max value: 36.0 at date: 2023-01-29T12:00:00+07:00
# Batch: 305, Max value: 37.0 at date: 2023-01-29T14:00:00+07:00
# Batch: 306, Max value: 37.0 at date: 2023-01-29T15:00:00+07:00
# Batch: 307, Max value: 37.0 at date: 2023-01-29T16:00:00+07:00
# Batch: 308, Max value: 38.0 at date: 2023-01-29T17:00:00+07:00
# Batch: 309, Max value: 38.0 at date: 2023-01-29T18:00:00+07:00
# Batch: 310, Max value: 39.0 at date: 2023-01-29T19:00:00+07:00
# Batch: 311, Max value: 39.0 at date: 2023-01-29T20:00:00+07:00
# Batch: 312, Max value: 39.0 at date: 2023-01-29T22:00:00+07:00
# Batch: 313, Max value: 39.0 at date: 2023-01-29T23:00:00+07:00
# Batch: 314, Max value: 40.0 at date: 2023-01-30T00:00:00+07:00
# Batch: 315, Max value: 40.0 at date: 2023-01-30T01:00:00+07:00
# Batch: 316, Max value: 41.0 at date: 2023-01-30T02:00:00+07:00
# Batch: 317, Max value: 41.0 at date: 2023-01-30T04:00:00+07:00
# Batch: 318, Max value: 40.0 at date: 2023-01-30T05:00:00+07:00
# Batch: 319, Max value: 40.0 at date: 2023-01-30T06:00:00+07:00
# Batch: 320, Max value: 40.0 at date: 2023-01-30T07:00:00+07:00
# Batch: 321, Max value: 41.0 at date: 2023-01-30T09:00:00+07:00
# Batch: 322, Max value: 41.0 at date: 2023-01-30T10:00:00+07:00
# Batch: 323, Max value: 42.0 at date: 2023-01-30T11:00:00+07:00
# Batch: 324, Max value: 43.0 at date: 2023-01-30T12:00:00+07:00
# Batch: 325, Max value: 43.0 at date: 2023-01-30T13:00:00+07:00
# Batch: 326, Max value: 44.0 at date: 2023-01-30T14:00:00+07:00
# Batch: 327, Max value: 44.0 at date: 2023-01-30T15:00:00+07:00
# Batch: 328, Max value: 43.0 at date: 2023-01-30T18:00:00+07:00
# Batch: 329, Max value: 43.0 at date: 2023-01-30T19:00:00+07:00
# Batch: 330, Max value: 43.0 at date: 2023-01-30T20:00:00+07:00
# Batch: 331, Max value: 44.0 at date: 2023-01-30T21:00:00+07:00
# Batch: 332, Max value: 44.0 at date: 2023-01-30T22:00:00+07:00
# Batch: 333, Max value: 45.0 at date: 2023-01-30T23:00:00+07:00
# Batch: 334, Max value: 46.0 at date: 2023-01-31T01:00:00+07:00
# Batch: 335, Max value: 46.0 at date: 2023-01-31T02:00:00+07:00
# Batch: 336, Max value: 47.0 at date: 2023-01-31T03:00:00+07:00
# Batch: 337, Max value: 49.0 at date: 2023-01-31T04:00:00+07:00
# Batch: 338, Max value: 50.0 at date: 2023-01-31T05:00:00+07:00
# Batch: 339, Max value: 54.0 at date: 2023-01-31T07:00:00+07:00
# Batch: 340, Max value: 56.0 at date: 2023-01-31T08:00:00+07:00
# Batch: 341, Max value: 59.0 at date: 2023-01-31T09:00:00+07:00
# ALERT! Batch: 342, Max value: 62.0 exceeded 60 at date: 2023-01-31T10:00:00+07:00!
# ALERT! Batch: 343, Max value: 63.0 exceeded 60 at date: 2023-01-31T11:00:00+07:00!
# ALERT! Batch: 344, Max value: 64.0 exceeded 60 at date: 2023-01-31T12:00:00+07:00!
# ALERT! Batch: 345, Max value: 65.0 exceeded 60 at date: 2023-01-31T13:00:00+07:00!
# ALERT! Batch: 346, Max value: 65.0 exceeded 60 at date: 2023-01-31T14:00:00+07:00!
# ALERT! Batch: 347, Max value: 66.0 exceeded 60 at date: 2023-01-31T15:00:00+07:00!
# ALERT! Batch: 348, Max value: 66.0 exceeded 60 at date: 2023-01-31T16:00:00+07:00!
# ALERT! Batch: 349, Max value: 69.0 exceeded 60 at date: 2023-01-31T18:00:00+07:00!
# ALERT! Batch: 350, Max value: 71.0 exceeded 60 at date: 2023-01-31T19:00:00+07:00!
# ALERT! Batch: 351, Max value: 72.0 exceeded 60 at date: 2023-01-31T20:00:00+07:00!
# ALERT! Batch: 352, Max value: 74.0 exceeded 60 at date: 2023-01-31T21:00:00+07:00!
# ALERT! Batch: 353, Max value: 77.0 exceeded 60 at date: 2023-01-31T22:00:00+07:00!
# ALERT! Batch: 354, Max value: 79.0 exceeded 60 at date: 2023-01-31T23:00:00+07:00!
# ALERT! Batch: 355, Max value: 80.0 exceeded 60 at date: 2023-02-01T00:00:00+07:00!
# ALERT! Batch: 356, Max value: 83.0 exceeded 60 at date: 2023-02-01T02:00:00+07:00!
# ALERT! Batch: 357, Max value: 85.0 exceeded 60 at date: 2023-02-01T03:00:00+07:00!
# ALERT! Batch: 358, Max value: 86.0 exceeded 60 at date: 2023-02-01T04:00:00+07:00!
# ALERT! Batch: 359, Max value: 87.0 exceeded 60 at date: 2023-02-01T05:00:00+07:00!
# ALERT! Batch: 360, Max value: 87.0 exceeded 60 at date: 2023-02-01T06:00:00+07:00!
# ALERT! Batch: 361, Max value: 88.0 exceeded 60 at date: 2023-02-01T07:00:00+07:00!
# ALERT! Batch: 362, Max value: 88.0 exceeded 60 at date: 2023-02-01T08:00:00+07:00!
# ALERT! Batch: 363, Max value: 87.0 exceeded 60 at date: 2023-02-01T09:00:00+07:00!
# ALERT! Batch: 364, Max value: 88.0 exceeded 60 at date: 2023-02-01T10:00:00+07:00!
# ALERT! Batch: 365, Max value: 89.0 exceeded 60 at date: 2023-02-01T11:00:00+07:00!
# ALERT! Batch: 366, Max value: 92.0 exceeded 60 at date: 2023-02-01T13:00:00+07:00!
# ALERT! Batch: 367, Max value: 93.0 exceeded 60 at date: 2023-02-01T14:00:00+07:00!
# ALERT! Batch: 368, Max value: 94.0 exceeded 60 at date: 2023-02-01T15:00:00+07:00!
# ALERT! Batch: 369, Max value: 96.0 exceeded 60 at date: 2023-02-01T16:00:00+07:00!
# ALERT! Batch: 370, Max value: 97.0 exceeded 60 at date: 2023-02-01T17:00:00+07:00!
# ALERT! Batch: 371, Max value: 98.0 exceeded 60 at date: 2023-02-01T18:00:00+07:00!
# ALERT! Batch: 372, Max value: 98.0 exceeded 60 at date: 2023-02-01T19:00:00+07:00!
# ALERT! Batch: 373, Max value: 98.0 exceeded 60 at date: 2023-02-01T20:00:00+07:00!
# ALERT! Batch: 374, Max value: 97.0 exceeded 60 at date: 2023-02-01T21:00:00+07:00!
# ALERT! Batch: 375, Max value: 97.0 exceeded 60 at date: 2023-02-01T22:00:00+07:00!
# ALERT! Batch: 376, Max value: 97.0 exceeded 60 at date: 2023-02-02T00:00:00+07:00!
# ALERT! Batch: 377, Max value: 97.0 exceeded 60 at date: 2023-02-02T01:00:00+07:00!
# ALERT! Batch: 378, Max value: 96.0 exceeded 60 at date: 2023-02-02T02:00:00+07:00!
# ALERT! Batch: 379, Max value: 96.0 exceeded 60 at date: 2023-02-02T04:00:00+07:00!
# ALERT! Batch: 380, Max value: 96.0 exceeded 60 at date: 2023-02-02T05:00:00+07:00!
# ALERT! Batch: 381, Max value: 97.0 exceeded 60 at date: 2023-02-02T06:00:00+07:00!
# ALERT! Batch: 382, Max value: 99.0 exceeded 60 at date: 2023-02-02T07:00:00+07:00!
# Batch: 383, Max value: 24.0 at date: 2023-02-14T09:00:00+07:00
# Batch: 384, Max value: 24.0 at date: 2023-02-14T10:00:00+07:00
# Batch: 385, Max value: 24.0 at date: 2023-02-14T11:00:00+07:00
# Batch: 386, Max value: 24.0 at date: 2023-02-14T13:00:00+07:00
# Batch: 387, Max value: 24.0 at date: 2023-02-14T14:00:00+07:00
# Batch: 388, Max value: 25.0 at date: 2023-02-14T16:00:00+07:00
# Batch: 389, Max value: 25.0 at date: 2023-02-14T17:00:00+07:00
# Batch: 390, Max value: 25.0 at date: 2023-02-14T19:00:00+07:00
# Batch: 391, Max value: 25.0 at date: 2023-02-14T20:00:00+07:00
# Batch: 392, Max value: 25.0 at date: 2023-02-14T21:00:00+07:00
# Batch: 393, Max value: 25.0 at date: 2023-02-14T22:00:00+07:00
# Batch: 394, Max value: 25.0 at date: 2023-02-14T23:00:00+07:00
# Batch: 395, Max value: 26.0 at date: 2023-02-15T01:00:00+07:00
# Batch: 396, Max value: 26.0 at date: 2023-02-15T02:00:00+07:00
# Batch: 397, Max value: 26.0 at date: 2023-02-15T03:00:00+07:00
# Batch: 398, Max value: 26.0 at date: 2023-02-15T04:00:00+07:00
# Batch: 399, Max value: 26.0 at date: 2023-02-15T05:00:00+07:00
# Batch: 400, Max value: 26.0 at date: 2023-02-15T06:00:00+07:00
# Batch: 401, Max value: 26.0 at date: 2023-02-15T07:00:00+07:00
# Batch: 402, Max value: 26.0 at date: 2023-02-15T09:00:00+07:00
# Batch: 403, Max value: 26.0 at date: 2023-02-15T10:00:00+07:00
# Batch: 404, Max value: 26.0 at date: 2023-02-15T11:00:00+07:00
# Batch: 405, Max value: 27.0 at date: 2023-02-15T12:00:00+07:00
# Batch: 406, Max value: 27.0 at date: 2023-02-15T13:00:00+07:00
# Batch: 407, Max value: 29.0 at date: 2023-02-15T14:00:00+07:00
# Batch: 408, Max value: 31.0 at date: 2023-02-15T16:00:00+07:00
# Batch: 409, Max value: 33.0 at date: 2023-02-15T17:00:00+07:00
# Batch: 410, Max value: 37.0 at date: 2023-02-15T21:00:00+07:00
# Batch: 411, Max value: 38.0 at date: 2023-02-15T22:00:00+07:00
# Batch: 412, Max value: 39.0 at date: 2023-02-15T23:00:00+07:00
# Batch: 413, Max value: 40.0 at date: 2023-02-16T00:00:00+07:00
# Batch: 414, Max value: 41.0 at date: 2023-02-16T01:00:00+07:00
# Batch: 415, Max value: 41.0 at date: 2023-02-16T02:00:00+07:00
# Batch: 416, Max value: 43.0 at date: 2023-02-16T04:00:00+07:00
# Batch: 417, Max value: 43.0 at date: 2023-02-16T05:00:00+07:00
# Batch: 418, Max value: 44.0 at date: 2023-02-16T06:00:00+07:00
# Batch: 419, Max value: 44.0 at date: 2023-02-16T07:00:00+07:00
# Batch: 420, Max value: 27.0 at date: 2023-03-20T03:00:00+07:00
# Batch: 421, Max value: 27.0 at date: 2023-03-20T09:00:00+07:00
# Batch: 422, Max value: 28.0 at date: 2023-03-21T09:00:00+07:00
# Batch: 423, Max value: 29.0 at date: 2023-03-21T22:00:00+07:00
# Batch: 424, Max value: 26.0 at date: 2023-03-23T00:00:00+07:00
# Batch: 425, Max value: 23.0 at date: 2023-03-24T13:00:00+07:00
# Batch: 426, Max value: 24.0 at date: 2023-03-25T03:00:00+07:00
# Batch: 427, Max value: 21.0 at date: 2023-03-27T02:00:00+07:00
# Batch: 428, Max value: 21.0 at date: 2023-03-27T21:00:00+07:00
# Batch: 429, Max value: 15.0 at date: 2023-03-29T03:00:00+07:00
# Batch: 430, Max value: 15.0 at date: 2023-03-29T04:00:00+07:00
# Batch: 431, Max value: 14.0 at date: 2023-03-29T20:00:00+07:00
# Batch: 432, Max value: 17.0 at date: 2023-03-30T22:00:00+07:00
# Batch: 433, Max value: 19.0 at date: 2023-03-31T22:00:00+07:00
# Batch: 434, Max value: 27.0 at date: 2023-04-03T09:00:00+07:00
# Batch: 435, Max value: 41.0 at date: 2023-04-04T13:00:00+07:00
# Batch: 436, Max value: 47.0 at date: 2023-04-04T21:00:00+07:00
# Batch: 437, Max value: 46.0 at date: 2023-04-05T04:00:00+07:00
# Batch: 438, Max value: 48.0 at date: 2023-04-05T20:00:00+07:00
# Batch: 439, Max value: 48.0 at date: 2023-04-05T21:00:00+07:00
# Batch: 440, Max value: 49.0 at date: 2023-04-05T22:00:00+07:00
# Batch: 441, Max value: 49.0 at date: 2023-04-06T23:00:00+07:00
# Batch: 442, Max value: 43.0 at date: 2023-04-07T14:00:00+07:00
# Batch: 443, Max value: 31.0 at date: 2023-04-08T03:00:00+07:00
# Batch: 444, Max value: 26.0 at date: 2023-04-09T12:00:00+07:00
# Batch: 445, Max value: 25.0 at date: 2023-04-09T19:00:00+07:00
# Batch: 446, Max value: 23.0 at date: 2023-04-10T01:00:00+07:00
# Batch: 447, Max value: 19.0 at date: 2023-04-10T23:00:00+07:00
# Batch: 448, Max value: 37.0 at date: 2023-04-12T20:00:00+07:00
# Batch: 449, Max value: 37.0 at date: 2023-04-12T22:00:00+07:00
# Batch: 450, Max value: 37.0 at date: 2023-04-12T23:00:00+07:00
# Batch: 451, Max value: 37.0 at date: 2023-04-13T01:00:00+07:00
# Batch: 452, Max value: 37.0 at date: 2023-04-13T02:00:00+07:00
# Batch: 453, Max value: 39.0 at date: 2023-04-13T07:00:00+07:00
# Batch: 454, Max value: 40.0 at date: 2023-04-13T08:00:00+07:00
# Batch: 455, Max value: 40.0 at date: 2023-04-13T09:00:00+07:00
# Batch: 456, Max value: 41.0 at date: 2023-04-13T10:00:00+07:00
# Batch: 457, Max value: 41.0 at date: 2023-04-13T11:00:00+07:00
# Batch: 458, Max value: 56.0 at date: 2023-04-15T14:00:00+07:00
# Batch: 459, Max value: 56.0 at date: 2023-04-15T15:00:00+07:00
# Batch: 460, Max value: 57.0 at date: 2023-04-15T16:00:00+07:00
# Batch: 461, Max value: 57.0 at date: 2023-04-15T17:00:00+07:00
# Batch: 462, Max value: 58.0 at date: 2023-04-15T19:00:00+07:00
# Batch: 463, Max value: 59.0 at date: 2023-04-15T20:00:00+07:00
# Batch: 464, Max value: 60.0 at date: 2023-04-15T21:00:00+07:00
# Batch: 465, Max value: 60.0 at date: 2023-04-15T22:00:00+07:00
# ALERT! Batch: 466, Max value: 61.0 exceeded 60 at date: 2023-04-15T23:00:00+07:00!
# ALERT! Batch: 467, Max value: 62.0 exceeded 60 at date: 2023-04-16T00:00:00+07:00!
# ALERT! Batch: 468, Max value: 62.0 exceeded 60 at date: 2023-04-16T01:00:00+07:00!
# ALERT! Batch: 469, Max value: 64.0 exceeded 60 at date: 2023-04-16T03:00:00+07:00!
# ALERT! Batch: 470, Max value: 64.0 exceeded 60 at date: 2023-04-16T04:00:00+07:00!
# ALERT! Batch: 471, Max value: 65.0 exceeded 60 at date: 2023-04-16T05:00:00+07:00!
# ALERT! Batch: 472, Max value: 66.0 exceeded 60 at date: 2023-04-16T06:00:00+07:00!
# ALERT! Batch: 473, Max value: 67.0 exceeded 60 at date: 2023-04-16T07:00:00+07:00!
# ALERT! Batch: 474, Max value: 68.0 exceeded 60 at date: 2023-04-16T08:00:00+07:00!
# ALERT! Batch: 475, Max value: 69.0 exceeded 60 at date: 2023-04-16T09:00:00+07:00!
# ALERT! Batch: 476, Max value: 70.0 exceeded 60 at date: 2023-04-16T10:00:00+07:00!
# ALERT! Batch: 477, Max value: 70.0 exceeded 60 at date: 2023-04-16T11:00:00+07:00!
# ALERT! Batch: 478, Max value: 69.0 exceeded 60 at date: 2023-04-16T12:00:00+07:00!
# ALERT! Batch: 479, Max value: 68.0 exceeded 60 at date: 2023-04-16T13:00:00+07:00!
# ALERT! Batch: 480, Max value: 68.0 exceeded 60 at date: 2023-04-16T15:00:00+07:00!
# ALERT! Batch: 481, Max value: 68.0 exceeded 60 at date: 2023-04-16T16:00:00+07:00!
# ALERT! Batch: 482, Max value: 67.0 exceeded 60 at date: 2023-04-16T17:00:00+07:00!
# ALERT! Batch: 483, Max value: 66.0 exceeded 60 at date: 2023-04-16T18:00:00+07:00!
# ALERT! Batch: 484, Max value: 66.0 exceeded 60 at date: 2023-04-16T19:00:00+07:00!
# ALERT! Batch: 485, Max value: 65.0 exceeded 60 at date: 2023-04-16T20:00:00+07:00!
# ALERT! Batch: 486, Max value: 63.0 exceeded 60 at date: 2023-04-16T22:00:00+07:00!
# ALERT! Batch: 487, Max value: 62.0 exceeded 60 at date: 2023-04-17T00:00:00+07:00!
# ALERT! Batch: 488, Max value: 62.0 exceeded 60 at date: 2023-04-17T01:00:00+07:00!
# ALERT! Batch: 489, Max value: 61.0 exceeded 60 at date: 2023-04-17T03:00:00+07:00!
# Batch: 490, Max value: 60.0 at date: 2023-04-17T04:00:00+07:00
# Batch: 491, Max value: 60.0 at date: 2023-04-17T05:00:00+07:00
# Batch: 492, Max value: 57.0 at date: 2023-04-17T08:00:00+07:00
# Batch: 493, Max value: 57.0 at date: 2023-04-17T09:00:00+07:00
# Batch: 494, Max value: 56.0 at date: 2023-04-17T10:00:00+07:00
# Batch: 495, Max value: 56.0 at date: 2023-04-17T11:00:00+07:00
# Batch: 496, Max value: 56.0 at date: 2023-04-17T12:00:00+07:00
# Batch: 497, Max value: 57.0 at date: 2023-04-17T13:00:00+07:00
# Batch: 498, Max value: 56.0 at date: 2023-04-17T14:00:00+07:00
# Batch: 499, Max value: 56.0 at date: 2023-04-17T15:00:00+07:00
# Batch: 500, Max value: 56.0 at date: 2023-04-17T16:00:00+07:00
# Batch: 501, Max value: 56.0 at date: 2023-04-17T17:00:00+07:00
# Batch: 502, Max value: 56.0 at date: 2023-04-17T18:00:00+07:00
# Batch: 503, Max value: 57.0 at date: 2023-04-17T21:00:00+07:00
# Batch: 504, Max value: 57.0 at date: 2023-04-17T22:00:00+07:00
# Batch: 505, Max value: 56.0 at date: 2023-04-17T23:00:00+07:00
# Batch: 506, Max value: 56.0 at date: 2023-04-18T00:00:00+07:00
# Batch: 507, Max value: 55.0 at date: 2023-04-18T01:00:00+07:00
# Batch: 508, Max value: 55.0 at date: 2023-04-18T02:00:00+07:00
# Batch: 509, Max value: 55.0 at date: 2023-04-18T03:00:00+07:00
# Batch: 510, Max value: 54.0 at date: 2023-04-18T04:00:00+07:00
# Batch: 511, Max value: 54.0 at date: 2023-04-18T05:00:00+07:00
# Batch: 512, Max value: 53.0 at date: 2023-04-18T06:00:00+07:00
# Batch: 513, Max value: 47.0 at date: 2023-04-19T13:00:00+07:00
# Batch: 514, Max value: 47.0 at date: 2023-04-19T14:00:00+07:00
# Batch: 515, Max value: 48.0 at date: 2023-04-19T16:00:00+07:00
# Batch: 516, Max value: 49.0 at date: 2023-04-19T17:00:00+07:00
# Batch: 517, Max value: 50.0 at date: 2023-04-19T18:00:00+07:00
# Batch: 518, Max value: 51.0 at date: 2023-04-19T19:00:00+07:00
# Batch: 519, Max value: 52.0 at date: 2023-04-19T20:00:00+07:00
# Batch: 520, Max value: 52.0 at date: 2023-04-19T21:00:00+07:00
# Batch: 521, Max value: 53.0 at date: 2023-04-19T23:00:00+07:00
# Batch: 522, Max value: 53.0 at date: 2023-04-20T00:00:00+07:00
# Batch: 523, Max value: 54.0 at date: 2023-04-20T01:00:00+07:00
# Batch: 524, Max value: 55.0 at date: 2023-04-20T02:00:00+07:00
# Batch: 525, Max value: 55.0 at date: 2023-04-20T03:00:00+07:00
# Batch: 526, Max value: 55.0 at date: 2023-04-20T04:00:00+07:00
# Batch: 527, Max value: 55.0 at date: 2023-04-20T05:00:00+07:00
# Batch: 528, Max value: 56.0 at date: 2023-04-20T06:00:00+07:00
# Batch: 529, Max value: 55.0 at date: 2023-04-20T09:00:00+07:00
# Batch: 530, Max value: 55.0 at date: 2023-04-20T10:00:00+07:00
# Batch: 531, Max value: 55.0 at date: 2023-04-20T11:00:00+07:00
# Batch: 532, Max value: 54.0 at date: 2023-04-20T12:00:00+07:00
# Batch: 533, Max value: 54.0 at date: 2023-04-20T13:00:00+07:00
# Batch: 534, Max value: 53.0 at date: 2023-04-20T15:00:00+07:00
# Batch: 535, Max value: 52.0 at date: 2023-04-20T16:00:00+07:00
# Batch: 536, Max value: 52.0 at date: 2023-04-20T17:00:00+07:00
# Batch: 537, Max value: 52.0 at date: 2023-04-20T18:00:00+07:00
# Batch: 538, Max value: 51.0 at date: 2023-04-20T21:00:00+07:00
# Batch: 539, Max value: 51.0 at date: 2023-04-20T22:00:00+07:00
# Batch: 540, Max value: 51.0 at date: 2023-04-20T23:00:00+07:00
# Batch: 541, Max value: 50.0 at date: 2023-04-21T00:00:00+07:00
# Batch: 542, Max value: 50.0 at date: 2023-04-21T01:00:00+07:00
# Batch: 543, Max value: 50.0 at date: 2023-04-21T02:00:00+07:00
# Batch: 544, Max value: 51.0 at date: 2023-04-21T04:00:00+07:00
# Batch: 545, Max value: 51.0 at date: 2023-04-21T05:00:00+07:00
# Batch: 546, Max value: 51.0 at date: 2023-04-21T06:00:00+07:00
# Batch: 547, Max value: 51.0 at date: 2023-04-21T07:00:00+07:00
# Batch: 548, Max value: 52.0 at date: 2023-04-21T08:00:00+07:00
# Batch: 549, Max value: 54.0 at date: 2023-04-21T09:00:00+07:00
# Batch: 550, Max value: 55.0 at date: 2023-04-21T11:00:00+07:00
# Batch: 551, Max value: 56.0 at date: 2023-04-21T12:00:00+07:00
# Batch: 552, Max value: 56.0 at date: 2023-04-21T13:00:00+07:00
# Batch: 553, Max value: 57.0 at date: 2023-04-21T14:00:00+07:00
# Batch: 554, Max value: 57.0 at date: 2023-04-21T15:00:00+07:00
# Batch: 555, Max value: 57.0 at date: 2023-04-21T16:00:00+07:00
# Batch: 556, Max value: 58.0 at date: 2023-04-21T17:00:00+07:00
# Batch: 557, Max value: 58.0 at date: 2023-04-21T18:00:00+07:00
# Batch: 558, Max value: 59.0 at date: 2023-04-21T21:00:00+07:00
# Batch: 559, Max value: 60.0 at date: 2023-04-21T22:00:00+07:00
# Batch: 560, Max value: 60.0 at date: 2023-04-21T23:00:00+07:00
# Batch: 561, Max value: 60.0 at date: 2023-04-22T01:00:00+07:00
# Batch: 562, Max value: 60.0 at date: 2023-04-22T02:00:00+07:00
# Batch: 563, Max value: 60.0 at date: 2023-04-22T03:00:00+07:00
# Batch: 564, Max value: 60.0 at date: 2023-04-22T04:00:00+07:00
# Batch: 565, Max value: 60.0 at date: 2023-04-22T06:00:00+07:00
# Batch: 566, Max value: 60.0 at date: 2023-04-22T07:00:00+07:00
# Batch: 567, Max value: 58.0 at date: 2023-04-23T08:00:00+07:00
# Batch: 568, Max value: 57.0 at date: 2023-04-23T09:00:00+07:00
# Batch: 569, Max value: 56.0 at date: 2023-04-23T10:00:00+07:00
# Batch: 570, Max value: 55.0 at date: 2023-04-23T11:00:00+07:00
# Batch: 571, Max value: 52.0 at date: 2023-04-23T13:00:00+07:00
# Batch: 572, Max value: 51.0 at date: 2023-04-23T14:00:00+07:00
# Batch: 573, Max value: 49.0 at date: 2023-04-23T15:00:00+07:00
# Batch: 574, Max value: 48.0 at date: 2023-04-23T16:00:00+07:00
# Batch: 575, Max value: 47.0 at date: 2023-04-23T17:00:00+07:00
# Batch: 576, Max value: 46.0 at date: 2023-04-23T18:00:00+07:00
# Batch: 577, Max value: 45.0 at date: 2023-04-23T19:00:00+07:00
# Batch: 578, Max value: 43.0 at date: 2023-04-23T20:00:00+07:00
# Batch: 579, Max value: 41.0 at date: 2023-04-23T22:00:00+07:00
# Batch: 580, Max value: 38.0 at date: 2023-04-24T00:00:00+07:00
# Batch: 581, Max value: 38.0 at date: 2023-04-24T01:00:00+07:00
# Batch: 582, Max value: 37.0 at date: 2023-04-24T02:00:00+07:00
# Batch: 583, Max value: 35.0 at date: 2023-04-24T03:00:00+07:00
# Batch: 584, Max value: 33.0 at date: 2023-04-24T05:00:00+07:00
# Batch: 585, Max value: 32.0 at date: 2023-04-24T06:00:00+07:00
# Batch: 586, Max value: 31.0 at date: 2023-04-24T07:00:00+07:00
# Batch: 587, Max value: 30.0 at date: 2023-04-24T09:00:00+07:00
# Batch: 588, Max value: 30.0 at date: 2023-04-24T10:00:00+07:00
# Batch: 589, Max value: 31.0 at date: 2023-04-24T12:00:00+07:00
# Batch: 590, Max value: 30.0 at date: 2023-04-24T14:00:00+07:00
# Batch: 591, Max value: 30.0 at date: 2023-04-24T15:00:00+07:00
# Batch: 592, Max value: 30.0 at date: 2023-04-24T16:00:00+07:00
# Batch: 593, Max value: 31.0 at date: 2023-04-24T17:00:00+07:00
# Batch: 594, Max value: 30.0 at date: 2023-04-24T19:00:00+07:00
# Batch: 595, Max value: 30.0 at date: 2023-04-24T21:00:00+07:00
# Batch: 596, Max value: 30.0 at date: 2023-04-24T22:00:00+07:00
# Batch: 597, Max value: 30.0 at date: 2023-04-24T23:00:00+07:00
# Batch: 598, Max value: 30.0 at date: 2023-04-25T00:00:00+07:00
# Batch: 599, Max value: 27.0 at date: 2023-04-26T10:00:00+07:00
# Batch: 600, Max value: 28.0 at date: 2023-04-26T11:00:00+07:00
# Batch: 601, Max value: 29.0 at date: 2023-04-26T12:00:00+07:00
# Batch: 602, Max value: 29.0 at date: 2023-04-26T13:00:00+07:00
# Batch: 603, Max value: 28.0 at date: 2023-04-26T14:00:00+07:00
# Batch: 604, Max value: 28.0 at date: 2023-04-26T16:00:00+07:00
# Batch: 605, Max value: 28.0 at date: 2023-04-26T17:00:00+07:00
# Batch: 606, Max value: 29.0 at date: 2023-04-26T18:00:00+07:00
# Batch: 607, Max value: 29.0 at date: 2023-04-26T19:00:00+07:00
# Batch: 608, Max value: 29.0 at date: 2023-04-26T21:00:00+07:00
# Batch: 609, Max value: 30.0 at date: 2023-04-26T22:00:00+07:00
# Batch: 610, Max value: 31.0 at date: 2023-04-26T23:00:00+07:00
# Batch: 611, Max value: 33.0 at date: 2023-04-27T00:00:00+07:00
# Batch: 612, Max value: 34.0 at date: 2023-04-27T01:00:00+07:00
# Batch: 613, Max value: 37.0 at date: 2023-04-27T03:00:00+07:00
# Batch: 614, Max value: 37.0 at date: 2023-04-27T04:00:00+07:00
# Batch: 615, Max value: 38.0 at date: 2023-04-27T05:00:00+07:00
# Batch: 616, Max value: 39.0 at date: 2023-04-27T06:00:00+07:00
# Batch: 617, Max value: 40.0 at date: 2023-04-27T07:00:00+07:00
# Batch: 618, Max value: 41.0 at date: 2023-04-27T08:00:00+07:00
# Batch: 619, Max value: 42.0 at date: 2023-04-27T09:00:00+07:00
# Batch: 620, Max value: 43.0 at date: 2023-04-27T10:00:00+07:00
# Batch: 621, Max value: 43.0 at date: 2023-04-27T12:00:00+07:00
# Batch: 622, Max value: 44.0 at date: 2023-04-27T13:00:00+07:00
# Batch: 623, Max value: 46.0 at date: 2023-04-27T14:00:00+07:00
# Batch: 624, Max value: 48.0 at date: 2023-04-27T15:00:00+07:00
# Batch: 625, Max value: 50.0 at date: 2023-04-27T17:00:00+07:00
# Batch: 626, Max value: 50.0 at date: 2023-04-27T18:00:00+07:00
# Batch: 627, Max value: 31.0 at date: 2023-04-29T00:00:00+07:00
# Batch: 628, Max value: 30.0 at date: 2023-04-29T01:00:00+07:00
# Batch: 629, Max value: 30.0 at date: 2023-04-29T02:00:00+07:00
# Batch: 630, Max value: 30.0 at date: 2023-04-29T03:00:00+07:00
# Batch: 631, Max value: 30.0 at date: 2023-04-29T04:00:00+07:00
# Batch: 632, Max value: 30.0 at date: 2023-04-29T05:00:00+07:00
# Batch: 633, Max value: 30.0 at date: 2023-04-29T06:00:00+07:00
# Batch: 634, Max value: 30.0 at date: 2023-04-29T07:00:00+07:00
# Batch: 635, Max value: 30.0 at date: 2023-04-29T08:00:00+07:00
# Batch: 636, Max value: 30.0 at date: 2023-04-29T10:00:00+07:00
# Batch: 637, Max value: 30.0 at date: 2023-04-29T11:00:00+07:00
# Batch: 638, Max value: 30.0 at date: 2023-04-29T12:00:00+07:00
# Batch: 639, Max value: 30.0 at date: 2023-04-29T13:00:00+07:00
# Batch: 640, Max value: 31.0 at date: 2023-04-29T14:00:00+07:00
# Batch: 641, Max value: 31.0 at date: 2023-04-29T15:00:00+07:00
# Batch: 642, Max value: 31.0 at date: 2023-04-29T17:00:00+07:00
# Batch: 643, Max value: 30.0 at date: 2023-04-29T18:00:00+07:00
# Batch: 644, Max value: 30.0 at date: 2023-04-29T19:00:00+07:00
# Batch: 645, Max value: 30.0 at date: 2023-04-29T20:00:00+07:00
# Batch: 646, Max value: 30.0 at date: 2023-04-29T21:00:00+07:00
# Batch: 647, Max value: 30.0 at date: 2023-04-29T22:00:00+07:00
# Batch: 648, Max value: 30.0 at date: 2023-04-30T00:00:00+07:00
# Batch: 649, Max value: 30.0 at date: 2023-04-30T01:00:00+07:00
# Batch: 650, Max value: 30.0 at date: 2023-04-30T02:00:00+07:00
# Batch: 651, Max value: 30.0 at date: 2023-04-30T03:00:00+07:00
# Batch: 652, Max value: 30.0 at date: 2023-04-30T04:00:00+07:00
# Batch: 653, Max value: 30.0 at date: 2023-04-30T05:00:00+07:00
# Batch: 654, Max value: 30.0 at date: 2023-04-30T06:00:00+07:00
# Batch: 655, Max value: 29.0 at date: 2023-04-30T07:00:00+07:00
# Batch: 656, Max value: 29.0 at date: 2023-04-30T08:00:00+07:00
# Batch: 657, Max value: 29.0 at date: 2023-04-30T09:00:00+07:00
# Batch: 658, Max value: 28.0 at date: 2023-04-30T11:00:00+07:00
# Batch: 659, Max value: 28.0 at date: 2023-04-30T12:00:00+07:00
# Batch: 660, Max value: 28.0 at date: 2023-04-30T13:00:00+07:00
# Batch: 661, Max value: 28.0 at date: 2023-04-30T14:00:00+07:00
# Batch: 662, Max value: 27.0 at date: 2023-04-30T15:00:00+07:00
# Batch: 663, Max value: 26.0 at date: 2023-04-30T17:00:00+07:00
# Batch: 664, Max value: 26.0 at date: 2023-04-30T18:00:00+07:00
# Batch: 665, Max value: 25.0 at date: 2023-04-30T19:00:00+07:00
# Batch: 666, Max value: 24.0 at date: 2023-04-30T21:00:00+07:00
# Batch: 667, Max value: 24.0 at date: 2023-04-30T22:00:00+07:00
# Batch: 668, Max value: 24.0 at date: 2023-04-30T23:00:00+07:00

# %%
query.stop()
