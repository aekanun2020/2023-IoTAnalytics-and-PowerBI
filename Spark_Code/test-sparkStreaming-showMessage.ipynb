# %%
# ปรับแต่งค่าการทำงานของ Spark
from pyspark.sql import SparkSession

spark = SparkSession.\
        builder.\
        appName("KafkaSubscribe").\
        master("spark://spark-master:7077").\
        config("spark.executor.memory", "1000m").\
        config("spark.executor.cores", "2").\
        config("spark.cores.max", "6").\
        config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.12:3.0.0").\
        getOrCreate()
# Out:
# Ivy Default Cache set to: /root/.ivy2/cache
# The jars for the packages stored in: /root/.ivy2/jars
# :: loading settings :: url = jar:file:/usr/local/lib/python3.9/dist-packages/pyspark/jars/ivy-2.4.0.jar!/org/apache/ivy/core/settings/ivysettings.xml
# org.apache.spark#spark-sql-kafka-0-10_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-3d2d773f-f234-4686-ad36-836cd39699ef;1.0
# 	confs: [default]
# 	found org.apache.spark#spark-sql-kafka-0-10_2.12;3.0.0 in central
# 	found org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.0.0 in central
# 	found org.apache.kafka#kafka-clients;2.4.1 in central
# 	found com.github.luben#zstd-jni;1.4.4-3 in central
# 	found org.lz4#lz4-java;1.7.1 in central
# 	found org.xerial.snappy#snappy-java;1.1.7.5 in central
# 	found org.slf4j#slf4j-api;1.7.30 in central
# 	found org.spark-project.spark#unused;1.0.0 in central
# 	found org.apache.commons#commons-pool2;2.6.2 in central
# :: resolution report :: resolve 616ms :: artifacts dl 14ms
# 	:: modules in use:
# 	com.github.luben#zstd-jni;1.4.4-3 from central in [default]
# 	org.apache.commons#commons-pool2;2.6.2 from central in [default]
# 	org.apache.kafka#kafka-clients;2.4.1 from central in [default]
# 	org.apache.spark#spark-sql-kafka-0-10_2.12;3.0.0 from central in [default]
# 	org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.0.0 from central in [default]
# 	org.lz4#lz4-java;1.7.1 from central in [default]
# 	org.slf4j#slf4j-api;1.7.30 from central in [default]
# 	org.spark-project.spark#unused;1.0.0 from central in [default]
# 	org.xerial.snappy#snappy-java;1.1.7.5 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   9   |   0   |   0   |   0   ||   9   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-3d2d773f-f234-4686-ad36-836cd39699ef
# 	confs: [default]
# 	0 artifacts copied, 9 already retrieved (0kB/14ms)
# 23/06/16 15:33:47 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
df = spark \
  .readStream \
  .format("kafka") \
  .option("kafka.bootstrap.servers", "10.128.0.12:9092") \
  .option("subscribe", "quickstart-events") \
  .load()

# %%
df
# Out:
# DataFrame[key: binary, value: binary, topic: string, partition: int, offset: bigint, timestamp: timestamp, timestampType: int]

# %%
df.printSchema()
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)

# %%
df = df.selectExpr("CAST(key AS STRING)", "CAST(value AS STRING)")

# %%
df.printSchema()
# Out:
# root
#  |-- key: string (nullable = true)
#  |-- value: string (nullable = true)

# %%
query = df.writeStream \
    .outputMode("append") \
    .format("console") \
    .trigger(processingTime='5 seconds') \
    .option("numRows", 3) \
    .start()

query.awaitTermination()
# Out:
# 23/06/16 15:33:56 WARN StreamingQueryManager: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-71cb27de-41dc-45cf-8e5c-c219ccef0e05. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# +----+--------------------+
#
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# +----+--------------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 3
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# +----+--------------------+
# only showing top 3 rows
# [Stage 4:>                                                          (0 + 1) / 1]
# -------------------------------------------
# Batch: 4
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# +----+--------------------+
# only showing top 3 rows
# -------------------------------------------
# Batch: 5
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# +----+--------------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 6
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# +----+--------------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 7
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# +----+--------------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 8
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# +----+--------------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 9
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# +----+--------------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 10
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# +----+--------------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 11
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# +----+--------------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 12
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# +----+--------------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 13
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# +----+--------------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 14
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# +----+--------------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 15
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# +----+--------------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 16
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# +----+--------------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 17
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# +----+--------------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 18
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# +----+--------------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 19
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# +----+--------------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 20
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# +----+--------------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 21
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# +----+--------------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 22
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# +----+--------------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 23
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# +----+--------------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 24
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# +----+--------------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 25
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# +----+--------------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 26
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# +----+--------------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 27
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# +----+--------------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 28
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# +----+--------------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 29
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# +----+--------------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 30
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# +----+--------------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 31
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# |null|{"locationId": "2...|
# +----+--------------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 32
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |null|{"locationId": "2...|
# +----+--------------------+
