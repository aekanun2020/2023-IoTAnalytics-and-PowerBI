# %%
# ปรับแต่งค่าการทำงานของ Spark
from pyspark.sql import SparkSession

spark = SparkSession.\
        builder.\
        appName("KafkaSubscribe").\
        master("spark://spark-master:7077").\
        config("spark.executor.memory", "1000m").\
        config("spark.executor.cores", "2").\
        config("spark.cores.max", "6").\
        config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.12:3.0.0").\
        getOrCreate()
# Out:
# Ivy Default Cache set to: /root/.ivy2/cache
# The jars for the packages stored in: /root/.ivy2/jars
# :: loading settings :: url = jar:file:/usr/local/lib/python3.9/dist-packages/pyspark/jars/ivy-2.4.0.jar!/org/apache/ivy/core/settings/ivysettings.xml
# org.apache.spark#spark-sql-kafka-0-10_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-abb9b5a3-77c4-4453-8707-0687af7fc4e8;1.0
# 	confs: [default]
# 	found org.apache.spark#spark-sql-kafka-0-10_2.12;3.0.0 in central
# 	found org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.0.0 in central
# 	found org.apache.kafka#kafka-clients;2.4.1 in central
# 	found com.github.luben#zstd-jni;1.4.4-3 in central
# 	found org.lz4#lz4-java;1.7.1 in central
# 	found org.xerial.snappy#snappy-java;1.1.7.5 in central
# 	found org.slf4j#slf4j-api;1.7.30 in central
# 	found org.spark-project.spark#unused;1.0.0 in central
# 	found org.apache.commons#commons-pool2;2.6.2 in central
# :: resolution report :: resolve 622ms :: artifacts dl 12ms
# 	:: modules in use:
# 	com.github.luben#zstd-jni;1.4.4-3 from central in [default]
# 	org.apache.commons#commons-pool2;2.6.2 from central in [default]
# 	org.apache.kafka#kafka-clients;2.4.1 from central in [default]
# 	org.apache.spark#spark-sql-kafka-0-10_2.12;3.0.0 from central in [default]
# 	org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.0.0 from central in [default]
# 	org.lz4#lz4-java;1.7.1 from central in [default]
# 	org.slf4j#slf4j-api;1.7.30 from central in [default]
# 	org.spark-project.spark#unused;1.0.0 from central in [default]
# 	org.xerial.snappy#snappy-java;1.1.7.5 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   9   |   0   |   0   |   0   ||   9   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-abb9b5a3-77c4-4453-8707-0687af7fc4e8
# 	confs: [default]
# 	0 artifacts copied, 9 already retrieved (0kB/16ms)
# 23/06/17 07:57:41 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
rawMetadata_df = spark \
  .readStream \
  .format("kafka") \
  .option("kafka.bootstrap.servers", "10.128.0.12:9092") \
  .option("subscribe", "quickstart-events") \
  .option("group.id", "Aekanun-Spark-App") \
  .load()

# %%
from pyspark.sql import functions as sparkf

# %%
rawMetadata_df.printSchema()
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)

# %%
# เลือกเฉพาะคอลัมน์ที่ต้องการ
onlyMetadata_df = rawMetadata_df.selectExpr("CAST(key AS STRING)", "CAST(value AS STRING)")

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import from_json, col

# Main schema
schema = StructType([
    StructField("locationId", StringType()),
    StructField("location", StringType()),
    StructField("parameter", StringType()),
    StructField("value", StringType()),
    StructField("date", StringType()),
    StructField("unit", StringType()),
    StructField("coordinates", StringType()),
    StructField("country", StringType()),
    StructField("city", StringType()),
    StructField("isMobile", StringType()),
    StructField("isAnalysis", StringType()),
    StructField("entity", StringType()),
    StructField("sensorType", StringType())
])

# Nested 'date' and 'coordinates' schema
date_schema = StructType([
    StructField("utc", StringType()),
    StructField("local", StringType())
])

coordinates_schema = StructType([
    StructField("latitude", DoubleType()),
    StructField("longitude", DoubleType())
])

# Parse the JSON string column and convert it to a struct.
parsedData_df = onlyMetadata_df.withColumn("data", from_json("value", schema))

# Select only the nested fields
unNested_df = parsedData_df.select("key", "data.*")

# Parse the nested 'date' and 'coordinates' fields
unNested_df = unNested_df.withColumn("date", from_json("date", date_schema))
unNested_df = unNested_df.withColumn("coordinates", from_json("coordinates", coordinates_schema))

# %%
query = unNested_df.writeStream \
    .outputMode("append") \
    .format("console") \
    .trigger(processingTime='5 seconds') \
    .option("numRows", 3) \
    .start()

query.awaitTermination()
# Out:
# 23/06/17 07:57:54 WARN StreamingQueryManager: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-bf01978d-7f0d-4fbb-bd1d-63569d330992. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +---+----------+--------+---------+-----+----+----+-----------+-------+----+--------+----------+------+----------+
# |key|locationId|location|parameter|value|date|unit|coordinates|country|city|isMobile|isAnalysis|entity|sensorType|
# +---+----------+--------+---------+-----+----+----+-----------+-------+----+--------+----------+------+----------+
# +---+----------+--------+---------+-----+----+----+-----------+-------+----+--------+----------+------+----------+
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# | key|locationId|            location|parameter|value|                date| unit|         coordinates|country|city|isMobile|isAnalysis|              entity|     sensorType|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 15.0|[2022-08-26T04:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 15.0|[2022-08-26T05:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 15.0|[2022-08-26T06:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# | key|locationId|            location|parameter|value|                date| unit|         coordinates|country|city|isMobile|isAnalysis|              entity|     sensorType|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 17.0|[2022-08-28T20:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 17.0|[2022-08-28T21:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 17.0|[2022-08-28T22:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# only showing top 3 rows
# -------------------------------------------
# Batch: 3
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# | key|locationId|            location|parameter|value|                date| unit|         coordinates|country|city|isMobile|isAnalysis|              entity|     sensorType|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 25.0|[2022-08-30T09:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 25.0|[2022-08-30T10:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 26.0|[2022-08-30T11:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 4
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# | key|locationId|            location|parameter|value|                date| unit|         coordinates|country|city|isMobile|isAnalysis|              entity|     sensorType|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 27.0|[2022-08-31T17:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 26.0|[2022-08-31T18:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 24.0|[2022-08-31T19:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 5
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# | key|locationId|            location|parameter|value|                date| unit|         coordinates|country|city|isMobile|isAnalysis|              entity|     sensorType|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 31.0|[2022-09-02T02:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 31.0|[2022-09-02T03:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 30.0|[2022-09-02T04:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 6
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# | key|locationId|            location|parameter|value|                date| unit|         coordinates|country|city|isMobile|isAnalysis|              entity|     sensorType|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 21.0|[2022-09-03T11:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 20.0|[2022-09-03T12:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 19.0|[2022-09-03T13:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 7
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# | key|locationId|            location|parameter|value|                date| unit|         coordinates|country|city|isMobile|isAnalysis|              entity|     sensorType|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 22.0|[2022-09-04T23:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 15.0|[2022-09-05T00:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 15.0|[2022-09-05T01:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 8
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# | key|locationId|            location|parameter|value|                date| unit|         coordinates|country|city|isMobile|isAnalysis|              entity|     sensorType|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 13.0|[2022-09-06T07:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 13.0|[2022-09-06T08:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 14.0|[2022-09-06T09:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 9
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# | key|locationId|            location|parameter|value|                date| unit|         coordinates|country|city|isMobile|isAnalysis|              entity|     sensorType|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 13.0|[2022-09-07T16:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 13.0|[2022-09-07T17:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 13.0|[2022-09-07T18:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 10
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# | key|locationId|            location|parameter|value|                date| unit|         coordinates|country|city|isMobile|isAnalysis|              entity|     sensorType|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 20.0|[2022-09-09T01:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 20.0|[2022-09-09T02:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 20.0|[2022-09-09T03:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 11
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# | key|locationId|            location|parameter|value|                date| unit|         coordinates|country|city|isMobile|isAnalysis|              entity|     sensorType|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 15.0|[2022-09-10T10:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 15.0|[2022-09-10T11:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 15.0|[2022-09-10T12:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 12
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# | key|locationId|            location|parameter|value|                date| unit|         coordinates|country|city|isMobile|isAnalysis|              entity|     sensorType|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 13.0|[2022-09-11T19:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 12.0|[2022-09-11T20:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 12.0|[2022-09-11T21:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 13
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# | key|locationId|            location|parameter|value|                date| unit|         coordinates|country|city|isMobile|isAnalysis|              entity|     sensorType|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 23.0|[2022-09-13T03:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 23.0|[2022-09-13T04:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 23.0|[2022-09-13T05:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 14
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# | key|locationId|            location|parameter|value|                date| unit|         coordinates|country|city|isMobile|isAnalysis|              entity|     sensorType|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 23.0|[2022-09-14T12:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 22.0|[2022-09-14T13:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 21.0|[2022-09-14T14:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 15
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# | key|locationId|            location|parameter|value|                date| unit|         coordinates|country|city|isMobile|isAnalysis|              entity|     sensorType|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 15.0|[2022-09-15T21:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 15.0|[2022-09-15T22:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 15.0|[2022-09-15T23:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 16
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# | key|locationId|            location|parameter|value|                date| unit|         coordinates|country|city|isMobile|isAnalysis|              entity|     sensorType|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 14.0|[2022-09-17T09:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 14.0|[2022-09-17T10:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 14.0|[2022-09-17T11:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 17
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# | key|locationId|            location|parameter|value|                date| unit|         coordinates|country|city|isMobile|isAnalysis|              entity|     sensorType|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 15.0|[2022-09-18T18:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 15.0|[2022-09-18T19:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 14.0|[2022-09-18T20:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 18
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# | key|locationId|            location|parameter|value|                date| unit|         coordinates|country|city|isMobile|isAnalysis|              entity|     sensorType|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 14.0|[2022-09-20T03:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 14.0|[2022-09-20T04:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 14.0|[2022-09-20T05:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 19
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# | key|locationId|            location|parameter|value|                date| unit|         coordinates|country|city|isMobile|isAnalysis|              entity|     sensorType|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 15.0|[2022-09-21T12:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 15.0|[2022-09-21T13:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 15.0|[2022-09-21T14:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 20
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# | key|locationId|            location|parameter|value|                date| unit|         coordinates|country|city|isMobile|isAnalysis|              entity|     sensorType|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 26.0|[2022-09-22T21:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 26.0|[2022-09-22T22:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 27.0|[2022-09-22T23:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 21
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# | key|locationId|            location|parameter|value|                date| unit|         coordinates|country|city|isMobile|isAnalysis|              entity|     sensorType|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 26.0|[2022-09-25T06:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 26.0|[2022-09-25T07:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 26.0|[2022-09-25T08:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 22
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# | key|locationId|            location|parameter|value|                date| unit|         coordinates|country|city|isMobile|isAnalysis|              entity|     sensorType|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 26.0|[2022-09-26T15:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 25.0|[2022-09-26T16:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 24.0|[2022-09-26T17:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 23
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# | key|locationId|            location|parameter|value|                date| unit|         coordinates|country|city|isMobile|isAnalysis|              entity|     sensorType|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 22.0|[2022-09-27T23:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 22.0|[2022-09-28T00:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 21.0|[2022-09-28T01:00...|µg/m³|[13.679226, 100.5...|     NA|    |   False|          |Governmental Orga...|reference grade|
# +----+----------+--------------------+---------+-----+--------------------+-----+--------------------+-------+----+--------+----------+--------------------+---------------+
# only showing top 3 rows

# %%
query.stop()
