# %%
# ปรับแต่งค่าการทำงานของ Spark
from pyspark.sql import SparkSession

spark = SparkSession.\
        builder.\
        appName("KafkaSubscribe").\
        master("spark://spark-master:7077").\
        config("spark.executor.memory", "1000m").\
        config("spark.executor.cores", "2").\
        config("spark.cores.max", "6").\
        config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.12:3.0.0").\
        getOrCreate()
# Out:
# Ivy Default Cache set to: /root/.ivy2/cache
# The jars for the packages stored in: /root/.ivy2/jars
# :: loading settings :: url = jar:file:/usr/local/lib/python3.9/dist-packages/pyspark/jars/ivy-2.4.0.jar!/org/apache/ivy/core/settings/ivysettings.xml
# org.apache.spark#spark-sql-kafka-0-10_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-f4896fa6-ba76-43bb-bebb-f45086c21e5a;1.0
# 	confs: [default]
# 	found org.apache.spark#spark-sql-kafka-0-10_2.12;3.0.0 in central
# 	found org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.0.0 in central
# 	found org.apache.kafka#kafka-clients;2.4.1 in central
# 	found com.github.luben#zstd-jni;1.4.4-3 in central
# 	found org.lz4#lz4-java;1.7.1 in central
# 	found org.xerial.snappy#snappy-java;1.1.7.5 in central
# 	found org.slf4j#slf4j-api;1.7.30 in central
# 	found org.spark-project.spark#unused;1.0.0 in central
# 	found org.apache.commons#commons-pool2;2.6.2 in central
# :: resolution report :: resolve 606ms :: artifacts dl 14ms
# 	:: modules in use:
# 	com.github.luben#zstd-jni;1.4.4-3 from central in [default]
# 	org.apache.commons#commons-pool2;2.6.2 from central in [default]
# 	org.apache.kafka#kafka-clients;2.4.1 from central in [default]
# 	org.apache.spark#spark-sql-kafka-0-10_2.12;3.0.0 from central in [default]
# 	org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.0.0 from central in [default]
# 	org.lz4#lz4-java;1.7.1 from central in [default]
# 	org.slf4j#slf4j-api;1.7.30 from central in [default]
# 	org.spark-project.spark#unused;1.0.0 from central in [default]
# 	org.xerial.snappy#snappy-java;1.1.7.5 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   9   |   0   |   0   |   0   ||   9   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-f4896fa6-ba76-43bb-bebb-f45086c21e5a
# 	confs: [default]
# 	0 artifacts copied, 9 already retrieved (0kB/13ms)
# 23/06/17 09:47:20 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
rawMetadata_df = spark \
  .readStream \
  .format("kafka") \
  .option("kafka.bootstrap.servers", "10.128.0.12:9092") \
  .option("subscribe", "quickstart-events") \
  .option("group.id", "Aekanun-Spark-App") \
  .load()

# %%
from pyspark.sql import functions as sparkf

# %%
rawMetadata_df.printSchema()
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)

# %%
# เลือกเฉพาะคอลัมน์ที่ต้องการ
onlyMetadata_df = rawMetadata_df.selectExpr("CAST(key AS STRING)", "CAST(value AS STRING)")

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import from_json, col

# Main schema
schema = StructType([
    StructField("locationId", StringType()),
    StructField("location", StringType()),
    StructField("parameter", StringType()),
    StructField("value", StringType()),
    StructField("date", StringType()),
    StructField("unit", StringType()),
    StructField("coordinates", StringType()),
    StructField("country", StringType()),
    StructField("city", StringType()),
    StructField("isMobile", StringType()),
    StructField("isAnalysis", StringType()),
    StructField("entity", StringType()),
    StructField("sensorType", StringType())
])

# Nested 'date' and 'coordinates' schema
date_schema = StructType([
    StructField("utc", StringType()),
    StructField("local", StringType())
])

coordinates_schema = StructType([
    StructField("latitude", DoubleType()),
    StructField("longitude", DoubleType())
])

# Parse the JSON string column and convert it to a struct.
parsedData_df = onlyMetadata_df.withColumn("data", from_json("value", schema))

# %%
parsedData_df.printSchema()
# Out:
# root
#  |-- key: string (nullable = true)
#  |-- value: string (nullable = true)
#  |-- data: struct (nullable = true)
#  |    |-- locationId: string (nullable = true)
#  |    |-- location: string (nullable = true)
#  |    |-- parameter: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |    |-- date: string (nullable = true)
#  |    |-- unit: string (nullable = true)
#  |    |-- coordinates: string (nullable = true)
#  |    |-- country: string (nullable = true)
#  |    |-- city: string (nullable = true)
#  |    |-- isMobile: string (nullable = true)
#  |    |-- isAnalysis: string (nullable = true)
#  |    |-- entity: string (nullable = true)
#  |    |-- sensorType: string (nullable = true)

# %%
# Select only the nested fields
unNested_df = parsedData_df.select("key", "data.*")

# %%
unNested_df.printSchema()
# Out:
# root
#  |-- key: string (nullable = true)
#  |-- locationId: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- parameter: string (nullable = true)
#  |-- value: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- unit: string (nullable = true)
#  |-- coordinates: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- isMobile: string (nullable = true)
#  |-- isAnalysis: string (nullable = true)
#  |-- entity: string (nullable = true)
#  |-- sensorType: string (nullable = true)

# %%
# Parse the JSON string column and convert it to a struct.
unNested_df.withColumn("data", from_json("value", schema))\
.withColumn("date", from_json("date", date_schema))\
.withColumn("coordinates", from_json("coordinates", coordinates_schema))\
.printSchema()
# Out:
# root
#  |-- key: string (nullable = true)
#  |-- locationId: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- parameter: string (nullable = true)
#  |-- value: string (nullable = true)
#  |-- date: struct (nullable = true)
#  |    |-- utc: string (nullable = true)
#  |    |-- local: string (nullable = true)
#  |-- unit: string (nullable = true)
#  |-- coordinates: struct (nullable = true)
#  |    |-- latitude: double (nullable = true)
#  |    |-- longitude: double (nullable = true)
#  |-- country: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- isMobile: string (nullable = true)
#  |-- isAnalysis: string (nullable = true)
#  |-- entity: string (nullable = true)
#  |-- sensorType: string (nullable = true)
#  |-- data: struct (nullable = true)
#  |    |-- locationId: string (nullable = true)
#  |    |-- location: string (nullable = true)
#  |    |-- parameter: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |    |-- date: string (nullable = true)
#  |    |-- unit: string (nullable = true)
#  |    |-- coordinates: string (nullable = true)
#  |    |-- country: string (nullable = true)
#  |    |-- city: string (nullable = true)
#  |    |-- isMobile: string (nullable = true)
#  |    |-- isAnalysis: string (nullable = true)
#  |    |-- entity: string (nullable = true)
#  |    |-- sensorType: string (nullable = true)

# %%
unNested_df.withColumn("data", from_json("value", schema))\
.withColumn("date", from_json("date", date_schema))\
.withColumn("coordinates", from_json("coordinates", coordinates_schema))\
.columns
# Out:
# ['key',
#  'locationId',
#  'location',
#  'parameter',
#  'value',
#  'date',
#  'unit',
#  'coordinates',
#  'country',
#  'city',
#  'isMobile',
#  'isAnalysis',
#  'entity',
#  'sensorType',
#  'data']

# %%
final_df = unNested_df.withColumn("data", from_json("value", schema))\
.withColumn("date", from_json("date", date_schema))\
.withColumn("coordinates", from_json("coordinates", coordinates_schema))\
.select('key',
 'locationId',
 'location',
 'parameter',
 'value',
 'date.*',
 'unit',
 'coordinates.*',
 'country',
 'city',
 'isMobile',
 'isAnalysis',
 'entity',
 'sensorType',
 'data')

# %%
final_df.printSchema()
# Out:
# root
#  |-- key: string (nullable = true)
#  |-- locationId: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- parameter: string (nullable = true)
#  |-- value: string (nullable = true)
#  |-- utc: string (nullable = true)
#  |-- local: string (nullable = true)
#  |-- unit: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- country: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- isMobile: string (nullable = true)
#  |-- isAnalysis: string (nullable = true)
#  |-- entity: string (nullable = true)
#  |-- sensorType: string (nullable = true)
#  |-- data: struct (nullable = true)
#  |    |-- locationId: string (nullable = true)
#  |    |-- location: string (nullable = true)
#  |    |-- parameter: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |    |-- date: string (nullable = true)
#  |    |-- unit: string (nullable = true)
#  |    |-- coordinates: string (nullable = true)
#  |    |-- country: string (nullable = true)
#  |    |-- city: string (nullable = true)
#  |    |-- isMobile: string (nullable = true)
#  |    |-- isAnalysis: string (nullable = true)
#  |    |-- entity: string (nullable = true)
#  |    |-- sensorType: string (nullable = true)

# %%
query = final_df.writeStream \
    .outputMode("append") \
    .format("console") \
    .trigger(processingTime='5 seconds') \
    .option("numRows", 3) \
    .start()

query.awaitTermination()
# Out:
# 23/06/17 09:47:31 WARN StreamingQueryManager: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-31f3ca1c-70e4-4d4a-acc7-5675619d434e. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +---+----------+--------+---------+-----+---+-----+----+--------+---------+-------+----+--------+----------+------+----------+----+
# |key|locationId|location|parameter|value|utc|local|unit|latitude|longitude|country|city|isMobile|isAnalysis|entity|sensorType|data|
# +---+----------+--------+---------+-----+---+-----+----+--------+---------+-------+----+--------+----------+------+----------+----+
# +---+----------+--------+---------+-----+---+-----+----+--------+---------+-------+----+--------+----------+------+----------+----+
# [Stage 1:>                                                          (0 + 1) / 1]
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 12.0|2022-09-19T08:00:...|2022-09-19T15:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 12.0|2022-09-19T09:00:...|2022-09-19T16:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 12.0|2022-09-19T10:00:...|2022-09-19T17:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 14.0|2022-09-20T09:00:...|2022-09-20T16:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 14.0|2022-09-20T10:00:...|2022-09-20T17:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 14.0|2022-09-20T11:00:...|2022-09-20T18:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 3
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 15.0|2022-09-21T15:00:...|2022-09-21T22:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 15.0|2022-09-21T16:00:...|2022-09-21T23:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 15.0|2022-09-21T17:00:...|2022-09-22T00:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 4
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 27.0|2022-09-22T23:00:...|2022-09-23T06:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 27.0|2022-09-23T00:00:...|2022-09-23T07:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 28.0|2022-09-23T01:00:...|2022-09-23T08:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
# -------------------------------------------
# Batch: 5
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 26.0|2022-09-25T09:00:...|2022-09-25T16:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 25.0|2022-09-25T10:00:...|2022-09-25T17:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 25.0|2022-09-25T11:00:...|2022-09-25T18:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 6
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 23.0|2022-09-26T19:00:...|2022-09-27T02:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 22.0|2022-09-26T20:00:...|2022-09-27T03:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 22.0|2022-09-26T21:00:...|2022-09-27T04:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 7
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 19.0|2022-09-28T05:00:...|2022-09-28T12:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 18.0|2022-09-28T06:00:...|2022-09-28T13:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 18.0|2022-09-28T07:00:...|2022-09-28T14:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 8
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 15.0|2022-09-29T15:00:...|2022-09-29T22:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 16.0|2022-09-29T16:00:...|2022-09-29T23:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 16.0|2022-09-29T17:00:...|2022-09-30T00:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 9
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 13.0|2022-10-01T00:00:...|2022-10-01T07:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 13.0|2022-10-01T01:00:...|2022-10-01T08:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 12.0|2022-10-01T02:00:...|2022-10-01T09:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 10
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 17.0|2022-10-02T10:00:...|2022-10-02T17:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 18.0|2022-10-02T11:00:...|2022-10-02T18:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 19.0|2022-10-02T12:00:...|2022-10-02T19:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 11
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 21.0|2022-10-03T20:00:...|2022-10-04T03:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 21.0|2022-10-03T21:00:...|2022-10-04T04:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 20.0|2022-10-03T22:00:...|2022-10-04T05:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 12
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 27.0|2022-10-05T06:00:...|2022-10-05T13:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 27.0|2022-10-05T07:00:...|2022-10-05T14:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 28.0|2022-10-05T08:00:...|2022-10-05T15:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 13
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 13.0|2022-10-10T04:00:...|2022-10-10T11:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 13.0|2022-10-10T05:00:...|2022-10-10T12:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 14.0|2022-10-10T06:00:...|2022-10-10T13:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 14
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 30.0|2022-10-12T04:00:...|2022-10-12T11:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 30.0|2022-10-12T05:00:...|2022-10-12T12:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 30.0|2022-10-12T06:00:...|2022-10-12T13:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 15
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 34.0|2022-10-13T13:00:...|2022-10-13T20:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 34.0|2022-10-13T14:00:...|2022-10-13T21:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 33.0|2022-10-13T15:00:...|2022-10-13T22:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 16
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 40.0|2022-10-14T23:00:...|2022-10-15T06:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 41.0|2022-10-15T00:00:...|2022-10-15T07:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 41.0|2022-10-15T01:00:...|2022-10-15T08:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 17
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 28.0|2022-10-16T09:00:...|2022-10-16T16:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 29.0|2022-10-16T10:00:...|2022-10-16T17:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 29.0|2022-10-16T11:00:...|2022-10-16T18:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 18
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 41.0|2022-10-17T19:00:...|2022-10-18T02:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 42.0|2022-10-17T20:00:...|2022-10-18T03:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 42.0|2022-10-17T21:00:...|2022-10-18T04:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 19
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 45.0|2022-10-19T04:00:...|2022-10-19T11:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 46.0|2022-10-19T05:00:...|2022-10-19T12:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 47.0|2022-10-19T06:00:...|2022-10-19T13:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 20
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 47.0|2022-10-20T14:00:...|2022-10-20T21:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 46.0|2022-10-20T15:00:...|2022-10-20T22:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 46.0|2022-10-20T16:00:...|2022-10-20T23:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 21
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 37.0|2022-10-22T00:00:...|2022-10-22T07:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 37.0|2022-10-22T01:00:...|2022-10-22T08:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 38.0|2022-10-22T02:00:...|2022-10-22T09:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 22
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 25.0|2022-10-23T10:00:...|2022-10-23T17:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 25.0|2022-10-23T11:00:...|2022-10-23T18:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 25.0|2022-10-23T12:00:...|2022-10-23T19:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 23
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 47.0|2022-10-25T20:00:...|2022-10-26T03:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 46.0|2022-10-25T21:00:...|2022-10-26T04:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 46.0|2022-10-25T22:00:...|2022-10-26T05:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 24
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 27.0|2022-10-27T05:00:...|2022-10-27T12:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 27.0|2022-10-27T06:00:...|2022-10-27T13:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 26.0|2022-10-27T07:00:...|2022-10-27T14:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 25
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 24.0|2022-10-28T15:00:...|2022-10-28T22:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 24.0|2022-10-28T16:00:...|2022-10-28T23:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 24.0|2022-10-28T17:00:...|2022-10-29T00:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 26
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 29.0|2022-10-30T01:00:...|2022-10-30T08:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 30.0|2022-10-30T02:00:...|2022-10-30T09:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 31.0|2022-10-30T03:00:...|2022-10-30T10:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 27
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 41.0|2022-10-31T11:00:...|2022-10-31T18:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 42.0|2022-10-31T12:00:...|2022-10-31T19:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 43.0|2022-10-31T13:00:...|2022-10-31T20:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 28
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 38.0|2022-11-01T21:00:...|2022-11-02T04:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 37.0|2022-11-01T22:00:...|2022-11-02T05:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 37.0|2022-11-01T23:00:...|2022-11-02T06:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 29
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 37.0|2022-11-03T07:00:...|2022-11-03T14:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 37.0|2022-11-03T08:00:...|2022-11-03T15:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 37.0|2022-11-03T09:00:...|2022-11-03T16:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 30
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 33.0|2022-11-04T16:00:...|2022-11-04T23:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# ...
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 96
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 42.0|2022-02-09T03:00:...|2022-02-09T10:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 41.0|2022-02-09T04:00:...|2022-02-09T11:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 39.0|2022-02-09T05:00:...|2022-02-09T12:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 97
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 27.0|2022-02-10T13:00:...|2022-02-10T20:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 27.0|2022-02-10T14:00:...|2022-02-10T21:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 26.0|2022-02-10T15:00:...|2022-02-10T22:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 98
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 22.0|2022-02-11T23:00:...|2022-02-12T06:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 22.0|2022-02-12T00:00:...|2022-02-12T07:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 23.0|2022-02-12T01:00:...|2022-02-12T08:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 99
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 34.0|2022-02-13T09:00:...|2022-02-13T16:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 33.0|2022-02-13T10:00:...|2022-02-13T17:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 33.0|2022-02-13T11:00:...|2022-02-13T18:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 100
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 25.0|2022-02-14T18:00:...|2022-02-15T01:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 25.0|2022-02-14T19:00:...|2022-02-15T02:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 25.0|2022-02-14T20:00:...|2022-02-15T03:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 101
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 41.0|2022-02-16T04:00:...|2022-02-16T11:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 42.0|2022-02-16T05:00:...|2022-02-16T12:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 42.0|2022-02-16T06:00:...|2022-02-16T13:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 102
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 47.0|2022-02-17T16:00:...|2022-02-17T23:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 45.0|2022-02-17T17:00:...|2022-02-18T00:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 44.0|2022-02-17T18:00:...|2022-02-18T01:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 103
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 16.0|2022-02-19T02:00:...|2022-02-19T09:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 16.0|2022-02-19T03:00:...|2022-02-19T10:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 16.0|2022-02-19T04:00:...|2022-02-19T11:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 104
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 12.0|2022-02-20T13:00:...|2022-02-20T20:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 11.0|2022-02-20T14:00:...|2022-02-20T21:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 11.0|2022-02-20T15:00:...|2022-02-20T22:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows
#
# -------------------------------------------
# Batch: 105
# -------------------------------------------
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# | key|locationId|            location|parameter|value|                 utc|               local| unit| latitude|longitude|country|city|isMobile|isAnalysis|              entity|     sensorType|          data|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# |null|    225577|Bank of Ayuthaya ...|     pm25| 23.0|2022-02-22T00:00:...|2022-02-22T07:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 23.0|2022-02-22T01:00:...|2022-02-22T08:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# |null|    225577|Bank of Ayuthaya ...|     pm25| 23.0|2022-02-22T02:00:...|2022-02-22T09:00:...|µg/m³|13.679226|100.54687|     NA|    |   False|          |Governmental Orga...|reference grade|[,,,,,,,,,,,,]|
# +----+----------+--------------------+---------+-----+--------------------+--------------------+-----+---------+---------+-------+----+--------+----------+--------------------+---------------+--------------+
# only showing top 3 rows

# %%
query.stop()
